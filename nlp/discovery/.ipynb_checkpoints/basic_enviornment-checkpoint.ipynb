# %%
# !pip install --upgrade "watson-developer-cloud>=1.4.0"
# Out:
# Requirement already up-to-date: watson-developer-cloud>=1.4.0 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (1.4.1)
# Requirement not upgraded as not directly required: Twisted>=13.2.0 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from watson-developer-cloud>=1.4.0) (18.4.0)
# Requirement not upgraded as not directly required: python-dateutil>=2.5.3 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from watson-developer-cloud>=1.4.0) (2.7.3)
# Requirement not upgraded as not directly required: autobahn>=0.10.9 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from watson-developer-cloud>=1.4.0) (18.6.1)
# Requirement not upgraded as not directly required: requests<3.0,>=2.0 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from watson-developer-cloud>=1.4.0) (2.19.1)
# Requirement not upgraded as not directly required: service-identity>=17.0.0 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from watson-developer-cloud>=1.4.0) (17.0.0)
# Requirement not upgraded as not directly required: pyOpenSSL>=16.2.0 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from watson-developer-cloud>=1.4.0) (18.0.0)
# Requirement not upgraded as not directly required: zope.interface>=4.4.2 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from Twisted>=13.2.0->watson-developer-cloud>=1.4.0) (4.5.0)
# Requirement not upgraded as not directly required: incremental>=16.10.1 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from Twisted>=13.2.0->watson-developer-cloud>=1.4.0) (17.5.0)
# Requirement not upgraded as not directly required: Automat>=0.3.0 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from Twisted>=13.2.0->watson-developer-cloud>=1.4.0) (0.7.0)
# Requirement not upgraded as not directly required: hyperlink>=17.1.1 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from Twisted>=13.2.0->watson-developer-cloud>=1.4.0) (18.0.0)
# Requirement not upgraded as not directly required: constantly>=15.1 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from Twisted>=13.2.0->watson-developer-cloud>=1.4.0) (15.1.0)
# Requirement not upgraded as not directly required: six>=1.5 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from python-dateutil>=2.5.3->watson-developer-cloud>=1.4.0) (1.11.0)
# Requirement not upgraded as not directly required: txaio>=2.10.0 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from autobahn>=0.10.9->watson-developer-cloud>=1.4.0) (2.10.0)
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from requests<3.0,>=2.0->watson-developer-cloud>=1.4.0) (3.0.4)
# Requirement not upgraded as not directly required: idna<2.8,>=2.5 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from requests<3.0,>=2.0->watson-developer-cloud>=1.4.0) (2.7)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from requests<3.0,>=2.0->watson-developer-cloud>=1.4.0) (2018.4.16)
# Requirement not upgraded as not directly required: urllib3<1.24,>=1.21.1 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from requests<3.0,>=2.0->watson-developer-cloud>=1.4.0) (1.23)
# Requirement not upgraded as not directly required: pyasn1-modules in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from service-identity>=17.0.0->watson-developer-cloud>=1.4.0) (0.2.1)
# Requirement not upgraded as not directly required: attrs in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from service-identity>=17.0.0->watson-developer-cloud>=1.4.0) (18.1.0)
# Requirement not upgraded as not directly required: pyasn1 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from service-identity>=17.0.0->watson-developer-cloud>=1.4.0) (0.4.3)
# Requirement not upgraded as not directly required: cryptography>=2.2.1 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from pyOpenSSL>=16.2.0->watson-developer-cloud>=1.4.0) (2.2.2)
# Requirement not upgraded as not directly required: setuptools in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from zope.interface>=4.4.2->Twisted>=13.2.0->watson-developer-cloud>=1.4.0) (39.1.0)
# Requirement not upgraded as not directly required: cffi>=1.7; platform_python_implementation != "PyPy" in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from cryptography>=2.2.1->pyOpenSSL>=16.2.0->watson-developer-cloud>=1.4.0) (1.11.5)
# Requirement not upgraded as not directly required: asn1crypto>=0.21.0 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from cryptography>=2.2.1->pyOpenSSL>=16.2.0->watson-developer-cloud>=1.4.0) (0.24.0)
# Requirement not upgraded as not directly required: pycparser in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (from cffi>=1.7; platform_python_implementation != "PyPy"->cryptography>=2.2.1->pyOpenSSL>=16.2.0->watson-developer-cloud>=1.4.0) (2.18)

# %%
import os
import sys
import errno
from watson_developer_cloud import DiscoveryV1
from dotenv import load_dotenv, find_dotenv
import json

# %%
try:
    load_dotenv(find_dotenv())
except IOError:
    print('warning: no .env file loaded')

# %% [markdown]
# # Create Discovery instance

# %%
discovery = DiscoveryV1(
              #url=os.getenv('DISCOVERY_URL'),
              username=os.getenv('DISCOVERY_USERNAME'),
              password=os.getenv('DISCOVERY_PASSWORD'),
              version="2018-03-05"
            )
environment_id = os.getenv('DISCOVERY_ENVIRONMENT_ID')
collection_id =  os.getenv('DISCOVERY_COLLECTION_ID')
configuration_id = os.getenv('DISCOVERY_CONFIGURATION_ID')

# %% [markdown]
# # List all fields

# %%
fields = discovery.list_fields(environment_id, [collection_id])
print(json.dumps(fields, indent=2))
# Out:
# {
#   "fields": [
#     {
#       "field": "anchor",
#       "type": "string"
#     },
#     {
#       "field": "enriched_text.entities.sentiment.score",
#       "type": "double"
#     },
#     {
#       "field": "enriched_text.sentiment.document.label",
#       "type": "string"
#     },
#     {
#       "field": "enriched_text.concepts.dbpedia_resource",
#       "type": "string"
#     },
#     {
#       "field": "extracted_metadata.file_type",
#       "type": "string"
#     },
#     {
#       "field": "enriched_text.concepts.text",
#       "type": "string"
#     },
#     {
#       "field": "enriched_text.concepts.relevance",
#       "type": "double"
#     },
#     {
#       "field": "enriched_text.categories.score",
#       "type": "double"
#     },
#     {
#       "field": "digest",
#       "type": "string"
#     },
#     {
#       "field": "url",
#       "type": "string"
#     },
#     {
#       "field": "host",
#       "type": "string"
#     },
#     {
#       "field": "enriched_text.entities.sentiment.label",
#       "type": "string"
#     },
#     {
#       "field": "enriched_text.entities.relevance",
#       "type": "double"
#     },
#     {
#       "field": "text",
#       "type": "string"
#     },
#     {
#       "field": "enriched_text.entities.count",
#       "type": "double"
#     },
#     {
#       "field": "enriched_text.entities.sentiment",
#       "type": "nested"
#     },
#     {
#       "field": "enriched_text.sentiment.document",
#       "type": "nested"
#     },
#     {
#       "field": "enriched_text.entities.text",
#       "type": "string"
#     },
#     {
#       "field": "enriched_text.entities",
#       "type": "nested"
#     },
#     {
#       "field": "enriched_text.entities.disambiguation.name",
#       "type": "string"
#     },
#     {
#       "field": "enriched_text.categories.label",
#       "type": "string"
#     },
#     {
#       "field": "id",
#       "type": "string"
#     },
#     {
#       "field": "boost",
#       "type": "string"
#     },
#     {
#       "field": "enriched_text.concepts",
#       "type": "nested"
#     },
#     {
#       "field": "tstamp",
#       "type": "date"
#     },
#     {
#       "field": "enriched_text.entities.disambiguation",
#       "type": "nested"
#     },
#     {
#       "field": "enriched_text.entities.type",
#       "type": "string"
#     },
#     {
#       "field": "extracted_metadata.sha1",
#       "type": "string"
#     },
#     {
#       "field": "enriched_text",
#       "type": "nested"
#     },
#     {
#       "field": "enriched_text.categories",
#       "type": "nested"
#     },
#     {
#       "field": "extracted_metadata",
#       "type": "nested"
#     },
#     {
#       "field": "enriched_text.entities.disambiguation.subtype",
#       "type": "string"
#     },
#     {
#       "field": "title",
#       "type": "string"
#     },
#     {
#       "field": "enriched_text.sentiment",
#       "type": "nested"
#     },
#     {
#       "field": "enriched_text.entities.disambiguation.dbpedia_resource",
#       "type": "string"
#     },
#     {
#       "field": "enriched_text.sentiment.document.score",
#       "type": "double"
#     },
#     {
#       "field": "extracted_metadata.filename",
#       "type": "string"
#     }
#   ]
# }

# %% [markdown]
# # List Configurations in environment

# %%
configs = discovery.list_configurations(environment_id)
print(json.dumps(configs, indent=2))
# Out:
# {
#   "configurations": [
#     {
#       "configuration_id": "4c720927-1619-479c-b5e0-c8c79c9803e6",
#       "name": "Default Configuration",
#       "description": "The configuration used by default when creating a new collection without specifying a configuration_id.",
#       "created": "2018-05-04T11:46:30.601Z",
#       "updated": "2018-05-04T11:46:30.601Z"
#     },
#     {
#       "configuration_id": "4d9f12a9-36fa-4876-b2d4-f3891341be60",
#       "name": "Default Contract Configuration",
#       "description": "Extract party, nature, and category from elements in PDFs.",
#       "created": "2018-05-04T11:46:36.080Z",
#       "updated": "2018-05-04T11:46:36.080Z"
#     },
#     {
#       "configuration_id": "0806bbdd-6bef-4882-8ba9-093c37749337",
#       "name": "sampleconfig",
#       "description": null,
#       "created": "2018-05-07T13:09:34.160Z",
#       "updated": "2018-05-07T13:09:34.160Z"
#     }
#   ]
# }

# %% [markdown]
# # Create collection progrmatically. Use this option in case you are not using collection created by tool. Uncomment the assigning collection to environment variable.

# %%
new_collection = discovery.create_collection(environment_id=environment_id, configuration_id=configuration_id, 
                                             name='Nature2', description='Create a Collection to hold natural calmaties information', 
                                             language='en')
print(json.dumps(new_collection, indent=2))
# **** Uncomment if you want to use the above created collection further ***
# collection_id = new_collection
# Out:
# {
#   "name": "Nature2",
#   "collection_id": "6cd34257-ac8c-43d5-b62f-61e0e9732eca",
#   "description": "Create a Collection to hold natural calmaties information",
#   "created": "2018-07-27T05:52:34.121Z",
#   "updated": "2018-07-27T05:52:34.121Z",
#   "configuration_id": "0806bbdd-6bef-4882-8ba9-093c37749337",
#   "language": "en",
#   "status": "active"
# }

# %% [markdown]
# # List Collections in given environment

# %%
collections = discovery.list_collections(environment_id)
print(json.dumps(collections, indent=2))
# Out:
# {
#   "collections": [
#     {
#       "collection_id": "e2688c58-055d-487d-921f-a41c0dde6a55",
#       "name": "MorganStanley",
#       "configuration_id": "0806bbdd-6bef-4882-8ba9-093c37749337",
#       "language": "en",
#       "status": "active",
#       "description": "",
#       "created": "2018-05-04T11:46:47.697Z",
#       "updated": "2018-06-17T19:18:25.451Z"
#     },
#     {
#       "collection_id": "be9d4ddb-863c-4e5f-8a5e-aeee9fc73bc0",
#       "name": "Nature",
#       "configuration_id": "4c720927-1619-479c-b5e0-c8c79c9803e6",
#       "language": "en",
#       "status": "active",
#       "description": null,
#       "created": "2018-07-05T17:39:47.081Z",
#       "updated": "2018-07-05T17:39:47.081Z"
#     }
#   ]
# }

# %% [markdown]
# # Create an environment

# %%
# Only one free environment is allowed per organization ---- so commenting
#response = discovery.create_environment(
#    name="my_environment",
#    description="My environment"
#)

#print(json.dumps(response, indent=2))

# %%
en_de = {"red" : "rot", "green" : "grün", "blue" : "blau", "yellow":"gelb"}
print (en_de)
print (en_de["red"])
de_fr = {"rot" : "rouge", "grün" : "vert", "blau" : "bleu", "gelb":"jaune"}
print ("The French word for red is: " + de_fr[en_de["red"]])
# Out:
# {'red': 'rot', 'green': 'grün', 'blue': 'blau', 'yellow': 'gelb'}
# rot
# The French word for red is: rouge

# %% [markdown]
# # List environments

# %%
environment_info = discovery.list_environments()
print(json.dumps(environment_info, indent=2))
# Out:
# {
#   "environments": [
#     {
#       "environment_id": "system",
#       "name": "Watson System Environment",
#       "description": "Shared system data sources",
#       "read_only": true
#     },
#     {
#       "environment_id": "162e8398-ceff-42ab-8710-655087535953",
#       "name": "byod",
#       "description": "",
#       "created": "2018-05-04T11:46:30.566Z",
#       "updated": "2018-05-04T11:46:30.566Z",
#       "read_only": false
#     }
#   ]
# }

# %% [markdown]
# # List environments and list collection for news environment(system)

# %%
environments = discovery.list_environments()
print(json.dumps(environments, indent=2))

#news_environments = [x for x in environments['environments'] if x['name'] == 'Watson Discovery News Environment']
news_environments = [x for x in environments['environments'] if x['name'] == 'Watson System Environment']
print(news_environments, len(news_environments))
news_environment_id = news_environments[0]['environment_id']
print('news environemnt details \n',json.dumps(news_environment_id, indent=2))

collections = discovery.list_collections(news_environment_id)
news_collections = [x for x in collections['collections']]
print('news collection')
print(json.dumps(news_collections, indent=2))
# Out:
# {
#   "environments": [
#     {
#       "environment_id": "system",
#       "name": "Watson System Environment",
#       "description": "Shared system data sources",
#       "read_only": true
#     },
#     {
#       "environment_id": "162e8398-ceff-42ab-8710-655087535953",
#       "name": "byod",
#       "description": "",
#       "created": "2018-05-04T11:46:30.566Z",
#       "updated": "2018-05-04T11:46:30.566Z",
#       "read_only": false
#     }
#   ]
# }
# [{'environment_id': 'system', 'name': 'Watson System Environment', 'description': 'Shared system data sources', 'read_only': True}] 1
# news environemnt details
#  "system"
# news collection
# [
#   {
#     "collection_id": "news-en",
#     "name": "news-en",
#     "language": "en",
#     "status": "active",
#     "description": "Watson News pre-enriched collection of curated news sources v2 (English)"
#   },
#   {
#     "collection_id": "news-de",
#     "name": "news-de",
#     "language": "de",
#     "status": "active",
#     "description": "Watson News pre-enriched collection of curated news sources v2 (German)"
#   },
#   {
#     "collection_id": "news-ko",
#     "name": "news-ko",
#     "language": "ko",
#     "status": "active",
#     "description": "Watson News pre-enriched collection of curated news sources v2 (Korean)"
#   },
#   {
#     "collection_id": "news-es",
#     "name": "news-es",
#     "language": "es",
#     "status": "active",
#     "description": "Watson News pre-enriched collection of curated news sources v2 (Spanish)"
#   }
# ]

# %% [markdown]
# # Add a document

# %%
print(os.getcwd())
print(os.path.join('/Users/rajeshgudikoti/Documents/rajesh/IBMDigital/Projects_docs/OHUM/samplereports/', 'spectracell_micronutrients.pdf'))
###### rb argument is passed as pdf is binary document ################
with open(os.path.join(os.getcwd(), '/Users/rajeshgudikoti/Documents/rajesh/IBMDigital/Projects_docs/OHUM/samplereports/', 'spectracell_micronutrients.pdf'),'rb') as fileinfo:
    add_doc = discovery.add_document(environment_id, collection_id, file=fileinfo, file_content_type='application/pdf',filename='spectracell_micronutrients.pdf')
print(json.dumps(add_doc, indent=2))
# Out:
# /Users/rajeshgudikoti/Documents/learning/nlp/discovery
# /Users/rajeshgudikoti/Documents/rajesh/IBMDigital/Projects_docs/OHUM/samplereports/spectracell_micronutrients.pdf

# %% [markdown]
# # Add a document reading online

# %%
# !pip install PyPDF2
# If importing module fails even after above command executed sucessfully then navigate to conda prompt and run 
# pip uninstall PyPDF2
# pip install PyPDF2
#https://stackoverflow.com/questions/39241643/no-module-named-pypdf2-error
# Out:
# Requirement already satisfied: PyPDF2 in /anaconda3/envs/tensorflow/lib/python3.6/site-packages (1.26.0)
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import PyPDF2, requests,io

# %%
print('reading online pdffile ')
url = 'https://www.ifc.org/wps/wcm/connect/8b796b004970c0199a7ada336b93d75f/DisERHandbook.pdf?MOD=AJPERES'
response = requests.get(url)
my_raw_data = response.content
#print('raw data ', my_raw_data)
pdf_content = io.BytesIO(my_raw_data)
pdf_reader = PyPDF2.PdfFileReader(pdf_content)

if pdf_reader.isEncrypted:
    pdf_reader.decrypt("")
    print('pdf content decrypted \n', pdf_reader.getPage(0).extractText())

else:
    print('pdf content \n ', pdf_reader.getPage(0).extractText())
num_pages = pdf_reader.getNumPages()
print(num_pages)
# Out:
# reading online pdffile
# pdf content
#   ˜˚˛˝˛˙ˆˇ˘˝˘ˆˇˆ
# ˇˆ˝ˇˆˆ˛˛
# ˘˚˝ˆ˘ˇ˘˛
#
# 72

# %%
url = 'https://www.ifc.org/wps/wcm/connect/8b796b004970c0199a7ada336b93d75f/DisERHandbook.pdf?MOD=AJPERES'
response = requests.get(url)
my_raw_data = response.content

with open("/Users/rajeshgudikoti/Documents/github_prj/cfc-fisrt-aid/DisERHandbook.pdf", 'wb') as my_data:
    my_data.write(my_raw_data)

open_pdf_file = open("my_pdf.pdf", 'rb')
read_pdf = PyPDF2.PdfFileReader(open_pdf_file)
if read_pdf.isEncrypted:
    read_pdf.decrypt("")
    print('pdf content decrypted \n', read_pdf.getPage(0).extractText())

else:
    print('pdf content \n',read_pdf.getPage(0).extractText())
# Out:
# pdf content
#  ˜˚˛˝˛˙ˆˇ˘˝˘ˆˇˆ
# ˇˆ˝ˇˆˆ˛˛
# ˘˚˝ˆ˘ˇ˘˛

# %% [markdown]
# # Get document details

# %%
print(add_doc['status'])
document_id = add_doc['document_id']
print(document_id)
# doc_info = discovery.get_document_status(environment_id, collection_id, '3ca7f868-630d-485a-a0ed-6dea26482604')
doc_info = discovery.get_document_status(environment_id, collection_id, document_id)
print(json.dumps(doc_info, indent=2))
# Out:
# processing
# 02bc2855-9b0f-448c-8edc-23f8dc64ec3b
# {
#   "document_id": "02bc2855-9b0f-448c-8edc-23f8dc64ec3b",
#   "notices": [],
#   "status": "available",
#   "status_description": "Document is successfully ingested and indexed with no warnings",
#   "filename": "spectracell_micronutrients.pdf",
#   "file_type": "pdf",
#   "sha1": "59566e8927157d7f8be82634e43ad0f931e3449c"
# }

# %% [markdown]
# # Update a document

# %%
#document_id = 'c346ec99-693f-4c0e-8f39-fd8633cb4725'
with open(os.path.join(os.getcwd(), '/Users/rajeshgudikoti/Documents/rajesh/IBMDigital/Projects_docs/OHUM/samplereports/', 'spectracell_micronutrients.pdf'),'rb') as fileinfo:
    add_updated_doc = discovery.update_document(environment_id, collection_id, document_id,
                                                file=fileinfo, 
                                                file_content_type='application/pdf',
                                                filename='spectracell_micronutrients.pdf')
print(json.dumps(add_updated_doc, indent=2))
# Out:
# {
#   "document_id": "02bc2855-9b0f-448c-8edc-23f8dc64ec3b",
#   "status": "processing"
# }

# %%
print(add_updated_doc['status'])
document_id = add_updated_doc['document_id']
print(document_id)
doc_info = discovery.get_document_status(environment_id, collection_id, document_id)
print(json.dumps(doc_info, indent=2))
# Out:
# processing
# 02bc2855-9b0f-448c-8edc-23f8dc64ec3b
# {
#   "document_id": "02bc2855-9b0f-448c-8edc-23f8dc64ec3b",
#   "notices": [],
#   "status": "available",
#   "status_description": "Document is successfully ingested and indexed with no warnings",
#   "filename": "spectracell_micronutrients.pdf",
#   "file_type": "pdf",
#   "sha1": "59566e8927157d7f8be82634e43ad0f931e3449c"
# }

# %%
# Delete a document

# %%
delete_doc = discovery.delete_document(environment_id, collection_id, document_id)
print(json.dumps(delete_doc, indent=2))
# Out:
# {
#   "document_id": "c346ec99-693f-4c0e-8f39-fd8633cb4725",
#   "status": "deleted"
# }

# %% [markdown]
# # query using discovery query langauge syntax

# %%
qopts = {'query': "entities.text:'Johnny Depp'"}
my_query = discovery.query('162e8398-ceff-42ab-8710-655087535953', 'e2688c58-055d-487d-921f-a41c0dde6a55', qopts)
print(json.dumps(my_query, indent=2))
# Out:
# {
#   "matching_results": 2,
#   "results": [
#     {
#       "id": "ef51f518fcb5b92a81f89df88342dd028427add685761d72612b54a2d15d7724",
#       "result_metadata": {
#         "score": 0
#       },
#       "digest": "ef2d9e5405c599b970ad8dae61ad26d7",
#       "url": "https://en.wikipedia.org/wiki/Watson_(computer)",
#       "host": "en.wikipedia.org",
#       "text": "Watson (computer) - Wikipedia Watson (computer) From Wikipedia, the free encyclopedia Jump to: navigation , search \"IBM Watson\" redirects here. For the IBM laboratory, see Thomas J. Watson Research Center . Watson's avatar , inspired by the IBM \" smarter planet \" logo [1] Watson is a question-answering computer system capable of answering questions posed in natural language , [2] developed in IBM 's DeepQA project by a research team led by principal investigator David Ferrucci . [3] Watson was named after IBM's first CEO, industrialist Thomas J. Watson . [4] [5] The computer system was initially developed to answer questions on the quiz show Jeopardy! [6] and, in 2011, the Watson computer system competed on Jeopardy! against legendary champions Brad Rutter and Ken Jennings [4] [7] winning the first place prize of $1 million. [8] In February 2013, IBM announced that Watson software system's first commercial application would be for utilization management decisions in lung cancer treatment at Memorial Sloan Kettering Cancer Center , New York City , in conjunction with health insurance company WellPoint . [9] IBM Watson's former business chief, Manoj Saxena, says that 90% of nurses in the field who use Watson now follow its guidance. [10] Contents 1 Description 1.1 Software 1.2 Hardware 1.3 Data 2 Operation 2.1 Comparison with human players 3 History 3.1 Development 3.2 Jeopardy! 3.2.1 Preparation 3.2.2 Practice match 3.2.3 First match 3.2.4 Second match 3.2.5 Final outcome 3.2.6 Philosophy 3.2.7 Match against members of the United States Congress 4 Current and future applications 4.1 Healthcare 4.2 IBM Watson Group 4.3 Chatterbot 4.4 Building Codes 4.5 Teaching Assistant 4.6 Weather forecasting 4.7 Fashion 4.8 Tax Preparation 5 See also 6 References 7 Further reading 8 External links 8.1 J! Archive 8.2 Videos Description[ edit ] The high-level architecture of IBM's DeepQA used in Watson [11] Watson was created as a question answering (QA) computing system that IBM built to apply advanced natural language processing , information retrieval , knowledge representation , automated reasoning , and machine learning technologies to the field of open domain question answering . [2] The key difference between QA technology and document search is that document search takes a keyword query and returns a list of documents, ranked in order of relevance to the query (often based on popularity and page ranking), while QA technology takes a question expressed in natural language, seeks to understand it in much greater detail, and returns a precise answer to the question. [12] When created, IBM stated that, \"more than 100 different techniques are used to analyze natural language, identify sources, find and generate hypotheses, find and score evidence, and merge and rank hypotheses.\" [13] In recent years, the Watson capabilities have been extended and the way in which Watson works has been changed to take advantage of new deployment models (Watson on IBM Cloud) and evolved machine learning capabilities and optimised hardware available to developers and researchers. It is no longer purely a question answering (QA) computing system designed from Q&A pairs but can now 'see', 'hear', 'read', 'talk', 'taste', 'understand', 'reason', 'interpret', 'learn' and 'recommend'. Software[ edit ] Watson uses IBM's DeepQA software and the Apache UIMA (Unstructured Information Management Architecture) framework. The system was written in various languages, including Java , C++ , and Prolog , and runs on the SUSE Linux Enterprise Server 11 operating system using the Apache Hadoop framework to provide distributed computing. [14] [15] [16] Hardware[ edit ] The system is workload-optimized, integrating massively parallel POWER7 processors and built on IBM's DeepQA technology, [17] which it uses to generate hypotheses, gather massive evidence, and analyze data. [2] Watson employs a cluster of ninety IBM Power 750 servers, each of which uses a 3.5\ ...
#       "boost": "1.0",
#       "tstamp": "1970-01-01T00:00:00.000Z",
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": 0.0101174,
#             "label": "positive"
#           }
#         },
#         "entities": [
#           {
#             "count": 108,
#             "sentiment": {
#               "score": -0.129836,
#               "label": "negative"
#             },
#             "text": "Thomas J. Watson",
#             "relevance": 0.843659,
#             "type": "Person",
#             "disambiguation": {
#               "subtype": [
#                 "CompanyFounder"
#               ],
#               "name": "Thomas J. Watson",
#               "dbpedia_resource": "http://dbpedia.org/resource/Thomas_J._Watson"
#             }
#           },
#           {
#             "count": 42,
#             "sentiment": {
#               "score": 0.0131585,
#               "label": "positive"
#             },
#             "text": "IBM",
#             "relevance": 0.418971,
#             "type": "Company",
#             "disambiguation": {
#               "subtype": [
#                 "SoftwareLicense",
#                 "OperatingSystemDeveloper",
#                 "ProcessorManufacturer",
#                 "SoftwareDeveloper",
#                 "CompanyFounder",
#                 "ProgrammingLanguageDesigner",
#                 "ProgrammingLanguageDeveloper"
#               ],
#               "name": "IBM",
#               "dbpedia_resource": "http://dbpedia.org/resource/IBM"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "IBM Watson Group",
#             "relevance": 0.319429,
#             "type": "Company"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "IBM Watson",
#             "relevance": 0.311595,
#             "type": "Company"
#           },
#           {
#             "count": 24,
#             "sentiment": {
#               "score": -0.104367,
#               "label": "negative"
#             },
#             "text": "Ken Jennings",
#             "relevance": 0.300849,
#             "type": "Person",
#             "disambiguation": {
#               "subtype": [
#                 "TVActor"
#               ],
#               "name": "Ken Jennings",
#               "dbpedia_resource": "http://dbpedia.org/resource/Ken_Jennings"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Thomas J. Watson Research Center",
#             "relevance": 0.282031,
#             "type": "Organization"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Watson software",
#             "relevance": 0.244489,
#             "type": "Company"
#           },
#           {
#             "count": 12,
#             "sentiment": {
#               "score": 0.182087,
#               "label": "positive"
#             },
#             "text": "Brad Rutter",
#             "relevance": 0.23794,
#             "type": "Person",
#             "disambiguation": {
#               "subtype": [
#                 "TVActor"
#               ],
#               "name": "Brad Rutter",
#               "dbpedia_resource": "http://dbpedia.org/resource/Brad_Rutter"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Watson",
#             "relevance": 0.207387,
#             "type": "Person"
#           },
#           {
#             "count": 7,
#             "sentiment": {
#               "score": -0.331876,
#               "label": "negative"
#             },
#             "text": "United States",
#             "relevance": 0.196897,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "Region",
#                 "AdministrativeDivision",
#                 "GovernmentalJurisdiction",
#                 "FilmEditor",
#                 "Country"
#               ],
#               "name": "United States",
#               "dbpedia_resource": "http://dbpedia.org/resource/United_States"
#             }
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "IBM Research",
#             "relevance": 0.169064,
#             "type": "Company"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.266428,
#               "label": "positive"
#             },
#             "text": "IBM Cloud",
#             "relevance": 0.159848,
#             "type": "Company"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Final Jeopardy",
#             "relevance": 0.138765,
#             "type": "PrintMedia"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "David Ferrucci",
#             "relevance": 0.136865,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Wikipedia",
#             "relevance": 0.127525,
#             "type": "Company"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.239685,
#               "label": "positive"
#             },
#             "text": "Manoj Saxena",
#             "relevance": 0.125873,
#             "type": "Person",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Manoj Saxena",
#               "dbpedia_resource": "http://dbpedia.org/resource/Manoj_Saxena"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.266428,
#               "label": "positive"
#             },
#             "text": "WellPoint",
#             "relevance": 0.124236,
#             "type": "Company",
#             "disambiguation": {
#               "subtype": [],
#               "name": "WellPoint",
#               "dbpedia_resource": "http://dbpedia.org/resource/WellPoint"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "New York City",
#             "relevance": 0.123939,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "PoliticalDistrict",
#                 "GovernmentalJurisdiction",
#                 "PlaceWithNeighborhoods",
#                 "WineRegion",
#                 "FilmScreeningVenue",
#                 "City"
#               ],
#               "name": "New York City",
#               "dbpedia_resource": "http://dbpedia.org/resource/New_York_City"
#             }
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Alex Trebek",
#             "relevance": 0.122739,
#             "type": "Person",
#             "disambiguation": {
#               "subtype": [
#                 "Actor",
#                 "FilmActor",
#                 "TVActor"
#               ],
#               "name": "Alex Trebek",
#               "dbpedia_resource": "http://dbpedia.org/resource/Alex_Trebek"
#             }
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": -0.474416,
#               "label": "negative"
#             },
#             "text": "Chicago",
#             "relevance": 0.120142,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Daily Double",
#             "relevance": 0.119616,
#             "type": "PrintMedia"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Unstructured Information Management Architecture",
#             "relevance": 0.119194,
#             "type": "PrintMedia"
#           },
#           {
#             "count": 5,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Toronto",
#             "relevance": 0.118763,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Garry Kasparov",
#             "relevance": 0.118203,
#             "type": "Person",
#             "disambiguation": {
#               "subtype": [
#                 "Politician",
#                 "AwardWinner",
#                 "TVActor"
#               ],
#               "name": "Garry Kasparov",
#               "dbpedia_resource": "http://dbpedia.org/resource/Garry_Kasparov"
#             }
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0.371001,
#               "label": "positive"
#             },
#             "text": "Stephen Baker",
#             "relevance": 0.117814,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Carnegie Mellon University",
#             "relevance": 0.11751,
#             "type": "Organization",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "Carnegie Mellon University",
#               "dbpedia_resource": "http://dbpedia.org/resource/Carnegie_Mellon_University"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.426213,
#               "label": "negative"
#             },
#             "text": "Teaching Assistant",
#             "relevance": 0.116214,
#             "type": "JobTitle"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.426213,
#               "label": "negative"
#             },
#             "text": "Memorial Sloan Kettering Cancer Center",
#             "relevance": 0.115283,
#             "type": "Facility"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.788689,
#               "label": "positive"
#             },
#             "text": "principal investigator",
#             "relevance": 0.114438,
#             "type": "JobTitle"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "CEO",
#             "relevance": 0.114005,
#             "type": "JobTitle"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Yago",
#             "relevance": 0.11358,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "U.S. government",
#             "relevance": 0.111105,
#             "type": "Organization",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Federal government of the United States",
#               "dbpedia_resource": "http://dbpedia.org/resource/Federal_government_of_the_United_States"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Dr. Chris Welty",
#             "relevance": 0.108033,
#             "type": "Person",
#             "disambiguation": {
#               "subtype": [
#                 "ComputerScientist"
#               ],
#               "name": "Chris Welty",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chris_Welty"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Tony Pearson",
#             "relevance": 0.107846,
#             "type": "Person",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Tony Pearson",
#               "dbpedia_resource": "http://dbpedia.org/resource/Tony_Pearson"
#             }
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0.300041,
#               "label": "positive"
#             },
#             "text": "John Rennie",
#             "relevance": 0.107437,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "MD Buyline",
#             "relevance": 0.107235,
#             "type": "Company"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.268577,
#               "label": "negative"
#             },
#             "text": "Welltok",
#             "relevance": 0.107099,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Paul Horn",
#             "relevance": 0.106404,
#             "type": "Person",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Paul Horn (musician)",
#               "dbpedia_resource": "http://dbpedia.org/resource/Paul_Horn_(musician)"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Rick Merritt",
#             "relevance": 0.10555,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Harry Friedman",
#             "relevance": 0.10482,
#             "type": "Person",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Harry Friedman",
#               "dbpedia_resource": "http://dbpedia.org/resource/Harry_Friedman"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "George Eyser",
#             "relevance": 0.104351,
#             "type": "Person",
#             "disambiguation": {
#               "subtype": [
#                 "OlympicAthlete"
#               ],
#               "name": "George Eyser",
#               "dbpedia_resource": "http://dbpedia.org/resource/George_Eyser"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Charles Lickel",
#             "relevance": 0.104252,
#             "type": "Person"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Ken Jennings",
#             "relevance": 0.974345,
#             "dbpedia_resource": "http://dbpedia.org/resource/Ken_Jennings"
#           },
#           {
#             "text": "IBM",
#             "relevance": 0.828856,
#             "dbpedia_resource": "http://dbpedia.org/resource/IBM"
#           },
#           {
#             "text": "Jeopardy! Ultimate Tournament of Champions",
#             "relevance": 0.663807,
#             "dbpedia_resource": "http://dbpedia.org/resource/Jeopardy!_Ultimate_Tournament_of_Champions"
#           },
#           {
#             "text": "Thomas J. Watson Research Center",
#             "relevance": 0.64194,
#             "dbpedia_resource": "http://dbpedia.org/resource/Thomas_J._Watson_Research_Center"
#           },
#           {
#             "text": "Brad Rutter",
#             "relevance": 0.605803,
#             "dbpedia_resource": "http://dbpedia.org/resource/Brad_Rutter"
#           },
#           {
#             "text": "Thomas J. Watson",
#             "relevance": 0.603538,
#             "dbpedia_resource": "http://dbpedia.org/resource/Thomas_J._Watson"
#           },
#           {
#             "text": "Jeopardy!",
#             "relevance": 0.598672,
#             "dbpedia_resource": "http://dbpedia.org/resource/Jeopardy!"
#           },
#           {
#             "text": "Computer",
#             "relevance": 0.568895,
#             "dbpedia_resource": "http://dbpedia.org/resource/Computer"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.372143,
#             "label": "/technology and computing"
#           },
#           {
#             "score": 0.26734,
#             "label": "/hobbies and interests/games/board games and puzzles"
#           },
#           {
#             "score": 0.264084,
#             "label": "/art and entertainment/movies and tv/television"
#           }
#         ]
#       },
#       "extracted_metadata": {
#         "sha1": "c8ac76fea5e0d24d45fb9a64215f953bc9d4117d",
#         "filename": "filename",
#         "file_type": "json"
#       },
#       "title": "Watson (computer) - Wikipedia"
#     },
#     {
#       "id": "05077636bde25bfc722ca73618a13c627dec7a3c5ce2fc08e106d65675ca85f6",
#       "result_metadata": {
#         "score": 0
#       },
#       "digest": "79afcd69cba94e323fe5a50008c47260",
#       "url": "https://en.wikipedia.org/wiki/Apache_Nutch",
#       "host": "en.wikipedia.org",
#       "text": "Apache Nutch - Wikipedia Apache Nutch From Wikipedia, the free encyclopedia Jump to: navigation , search Apache Nutch Screenshot Nutch Web Interface Search Developer(s) Apache Software Foundation Stable release 1.13 and 2.3.1 / April\u00a02,\u00a02017\u00a0(2017-04-02) Development status Active Written in Java Operating system Cross-platform Type Web Crawler License Apache License 2.0 Website nutch.apache.org Apache Nutch is a highly extensible and scalable open source web crawler software project. Contents 1 Features 2 History 2.1 Release history 3 Advantages 4 Scalability 5 Related projects 6 Search engines built with Nutch 7 See also 8 References 9 Bibliography 10 External links Features[ edit ] Nutch is coded entirely in the Java programming language , but data is written in language-independent formats. It has a highly modular architecture, allowing developers to create plug-ins for media-type parsing, data retrieval, querying and clustering. The fetcher (\"robot\" or \" web crawler \") has been written from scratch specifically for this project. History[ edit ] Nutch originated with Doug Cutting , creator of both Lucene and Hadoop , and Mike Cafarella . In June, 2003, a successful 100-million-page demonstration system was developed. To meet the multi-machine processing needs of the crawl and index tasks, the Nutch project has also implemented a MapReduce facility and a distributed file system . The two facilities have been spun out into their own subproject, called Hadoop . In January, 2005, Nutch joined the Apache Incubator , from which it graduated to become a subproject of Lucene in June of that same year. Since April, 2010, Nutch has been considered an independent, top level project of the Apache Software Foundation . [1] In February 2014 the Common Crawl project adopted Nutch for its open, large-scale web crawl. [2] While it was once a goal for the Nutch project to release a global large-scale web search engine, that is no longer the case.[ citation needed ] Release history[ edit ] Version Release date Description 1.1 2010-06-06 This release includes several major upgrades of existing libraries (Hadoop, Solr, Tika, etc.) on which Nutch depends. Various bug fixes, and speedups (e.g., to Fetcher2) have also been included. 1.2 2010-10-24 This release includes several improvements (addition of parse-html as a selectable parser again, configurable per-field indexing), new features (including adding timing information to all Tool classes, and implementation of parser timeouts), and bug fixes (fixing an NPE in distributed search, fixing of XML formatting issues per Document fields). 1.3 2011-06-07 This release includes several improvements (improved RSS parsing support, tighter integration with Apache Tika, external parsing support, improved language identification and an order of magnitude smaller source release tarball\u2014only about 2\u00a0MB). 1.4 2011-11-26 This release includes several improvements including allowing Parsers to declare support for multiple MIME types, configurable Fetcher Queue depth, Fetcher speed improvements, tighter Tika integration, and support for HTTP auth in Solr indexing. 1.5 2012-06-07 This release includes several improvements including upgrades of several major components including Tika 1.1 and Hadoop 1.0.0, improvements to LinkRank and WebGraph elements as well as a number of new plugins covering blacklisting, filtering and parsing to name a few. 2.0 2012-07-07 This release offers users an edition focused on large scale crawling which builds on storage abstraction (via Apache Gora\u2122) for big data stores such as Apache Accumulo\u2122, Apache Avro\u2122, Apache Cassandra\u2122, Apache HBase\u2122, HDFS\u2122, an in memory data store and various high profile SQL stores. 1.5.1 2012-07-10 This release is a maintenance release of the popular 1.5.X mainstream version of Nutch which has been widely adopted within the community. 2.1 2012-10-05 This release continues to provide ...
#       "boost": "1.0",
#       "tstamp": "1970-01-01T00:00:00.000Z",
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": 0.453531,
#             "label": "positive"
#           }
#         },
#         "entities": [
#           {
#             "count": 11,
#             "sentiment": {
#               "score": 0.648211,
#               "label": "positive"
#             },
#             "text": "Nutch",
#             "relevance": 0.934035,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           },
#           {
#             "count": 6,
#             "sentiment": {
#               "score": -0.285485,
#               "label": "negative"
#             },
#             "text": "Nutch",
#             "relevance": 0.62608,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Nutch",
#             "relevance": 0.493384,
#             "type": "Company"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Apache Software Foundation",
#             "relevance": 0.361061,
#             "type": "Organization",
#             "disambiguation": {
#               "subtype": [
#                 "Company",
#                 "Non-ProfitOrganisation",
#                 "SoftwareDeveloper"
#               ],
#               "name": "Apache Software Foundation",
#               "dbpedia_resource": "http://dbpedia.org/resource/Apache_Software_Foundation"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Apache Software Foundation",
#             "relevance": 0.262873,
#             "type": "Company",
#             "disambiguation": {
#               "subtype": [
#                 "Non-ProfitOrganisation",
#                 "SoftwareDeveloper"
#               ],
#               "name": "Apache Software Foundation",
#               "dbpedia_resource": "http://dbpedia.org/resource/Apache_Software_Foundation"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Apache Software Foundation.",
#             "relevance": 0.245869,
#             "type": "Organization"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Developer",
#             "relevance": 0.182416,
#             "type": "JobTitle"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Wikia",
#             "relevance": 0.176413,
#             "type": "Company",
#             "disambiguation": {
#               "subtype": [
#                 "Website"
#               ],
#               "name": "Wikia",
#               "dbpedia_resource": "http://dbpedia.org/resource/Wikia"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Mike Cafarella",
#             "relevance": 0.174415,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.285485,
#               "label": "negative"
#             },
#             "text": "Doug Cutting",
#             "relevance": 0.172883,
#             "type": "Person",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Doug Cutting",
#               "dbpedia_resource": "http://dbpedia.org/resource/Doug_Cutting"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.343024,
#               "label": "positive"
#             },
#             "text": "TREC",
#             "relevance": 0.172048,
#             "type": "Organization",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "Facility",
#                 "Building"
#               ],
#               "name": "WindShare",
#               "dbpedia_resource": "http://dbpedia.org/resource/WindShare"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "ISBN",
#             "relevance": 0.166314,
#             "type": "PrintMedia"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Official",
#             "relevance": 0.160342,
#             "type": "JobTitle"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "IBM Research",
#             "relevance": 0.159921,
#             "type": "Company"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Sami",
#             "relevance": 0.154992,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Wikidata",
#             "relevance": 0.145461,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Wikipedia",
#             "relevance": 0.145145,
#             "type": "Company"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Webcrawler",
#             "relevance": 0.143613,
#             "type": "Company"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "829636128",
#             "relevance": 0.143613,
#             "type": "Quantity"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "1.0",
#             "relevance": 0.143613,
#             "type": "Quantity"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "2\u00a0MB",
#             "relevance": 0.143613,
#             "type": "Quantity"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Web crawler",
#             "relevance": 0.935321,
#             "dbpedia_resource": "http://dbpedia.org/resource/Web_crawler"
#           },
#           {
#             "text": "Web search engine",
#             "relevance": 0.456734,
#             "dbpedia_resource": "http://dbpedia.org/resource/Web_search_engine"
#           },
#           {
#             "text": "Wikia Search",
#             "relevance": 0.362581,
#             "dbpedia_resource": "http://dbpedia.org/resource/Wikia_Search"
#           },
#           {
#             "text": "Nutch",
#             "relevance": 0.355445,
#             "dbpedia_resource": "http://dbpedia.org/resource/Nutch"
#           },
#           {
#             "text": "Apache Software Foundation",
#             "relevance": 0.325955,
#             "dbpedia_resource": "http://dbpedia.org/resource/Apache_Software_Foundation"
#           },
#           {
#             "text": "Bing",
#             "relevance": 0.319352,
#             "dbpedia_resource": "http://dbpedia.org/resource/Bing_(search_engine)"
#           },
#           {
#             "text": "Information retrieval",
#             "relevance": 0.315933,
#             "dbpedia_resource": "http://dbpedia.org/resource/Information_retrieval"
#           },
#           {
#             "text": "Doug Cutting",
#             "relevance": 0.30405,
#             "dbpedia_resource": "http://dbpedia.org/resource/Doug_Cutting"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.517707,
#             "label": "/technology and computing/software/databases"
#           },
#           {
#             "score": 0.458037,
#             "label": "/technology and computing/software"
#           },
#           {
#             "score": 0.34936,
#             "label": "/technology and computing/programming languages/java"
#           }
#         ]
#       },
#       "extracted_metadata": {
#         "sha1": "01a6b665cae52c1161e10fa50947c5a6133995fe",
#         "filename": "filename",
#         "file_type": "json"
#       },
#       "title": "Apache Nutch - Wikipedia"
#     }
#   ]
# }

# %%
dict={'a':1,'b':2,'c':3}
dict_list=[]
dict_list=list(dict.values())
print (dict_list)
# Out:
# [1, 2, 3]

# %%
with open('expansions.json', 'r') as f:
        datastore = json.load(f)
print('datastore \n',datastore)
datastorelist = datastore.values()
print('datastorelist \n',datastorelist)
# Out:
# datastore
#  {'expansions': [{'expanded_terms': ['car', 'automobile', 'sedan', 'suv', 'sport utility vehicle', 'motor vehicle']}, {'input_terms': ['weekday', 'week day'], 'expanded_terms': ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']}, {'input_terms': ['weekend', 'week end'], 'expanded_terms': ['saturday', 'sunday']}]}
# datastorelist
#  dict_values([[{'expanded_terms': ['car', 'automobile', 'sedan', 'suv', 'sport utility vehicle', 'motor vehicle']}, {'input_terms': ['weekday', 'week day'], 'expanded_terms': ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']}, {'input_terms': ['weekend', 'week end'], 'expanded_terms': ['saturday', 'sunday']}]])

# %%
expansions_list = discovery.list_expansions(environment_id, collection_id)
print(type(expansions_list), '\t', type(list(expansions_list.values())), (list(expansions_list.values())[0]))
print(json.dumps(expansions_list, indent=2))
expansion = json.dumps({
   "expansions": [
     {
       "expanded_terms": [
         "car",
         "automobile",
         "motor vehicle"
       ]
     }
   ]
 })
with open('expansions.json', 'r') as f:
        datastore = json.load(f)
print('datastore \t',datastore, '\n',type(datastore))
expansion_json = json.loads(expansion)

#d = {"age":25} 
kwargs = {"age":25}

datastore_list = list(datastore.values())
print(type(expansion),'\t',expansion)
print(type(expansion_json),'\t',expansion_json)
# ************ create is failing ***************** #
#expansions_list = discovery.create_expansions(environment_id,collection_id,list(datastore))
expansions_list = discovery.list_expansions(environment_id, collection_id)

print('expansions_list ********** \n',json.dumps(expansions_list, indent=2))
# Out:
# <class 'dict'> 	 <class 'list'> [{'expanded_terms': ['car', 'automobile', 'sedan', 'suv', 'sport utility vehicle', 'motor vehicle']}, {'input_terms': ['weekday', 'week day'], 'expanded_terms': ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']}, {'input_terms': ['weekend', 'week end'], 'expanded_terms': ['saturday', 'sunday']}]
# {
#   "expansions": [
#     {
#       "expanded_terms": [
#         "car",
#         "automobile",
#         "sedan",
#         "suv",
#         "sport utility vehicle",
#         "motor vehicle"
#       ]
#     },
#     {
#       "input_terms": [
#         "weekday",
#         "week day"
#       ],
#       "expanded_terms": [
#         "monday",
#         "tuesday",
#         "wednesday",
#         "thursday",
#         "friday"
#       ]
#     },
#     {
#       "input_terms": [
#         "weekend",
#         "week end"
#       ],
#       "expanded_terms": [
#         "saturday",
#         "sunday"
#       ]
#     }
#   ]
# }
# datastore 	 {'expansions': [{'expanded_terms': ['car', 'automobile', 'sedan', 'suv', 'sport utility vehicle', 'motor vehicle']}, {'input_terms': ['weekday', 'week day'], 'expanded_terms': ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']}, {'input_terms': ['weekend', 'week end'], 'expanded_terms': ['saturday', 'sunday']}]}
#  <class 'dict'>
# <class 'str'> 	 {"expansions": [{"expanded_terms": ["car", "automobile", "motor vehicle"]}]}
# <class 'dict'> 	 {'expansions': [{'expanded_terms': ['car', 'automobile', 'motor vehicle']}]}
# expansions_list {
#   "expansions": [
#     {
#       "expanded_terms": [
#         "car",
#         "automobile",
#         "sedan",
#         "suv",
#         "sport utility vehicle",
#         "motor vehicle"
#       ]
#     },
#     {
#       "input_terms": [
#         "weekday",
#         "week day"
#       ],
#       "expanded_terms": [
#         "monday",
#         "tuesday",
#         "wednesday",
#         "thursday",
#         "friday"
#       ]
#     },
#     {
#       "input_terms": [
#         "weekend",
#         "week end"
#       ],
#       "expanded_terms": [
#         "saturday",
#         "sunday"
#       ]
#     }
#   ]
# }

# %%
import json

r = {'is_claimed': 'True', 'rating': 3.5}
print(type(r)) #Output
r = json.dumps(r)
loaded_r = json.loads(r)
loaded_r['rating'] #Output 3.5
print(type(r)) #Output str
print(type(loaded_r)) #Output dict
# Out:
# <class 'dict'>
# <class 'str'>
# <class 'dict'>

# %%
def list_collections(self, environment_id):
        """
        Retrieves information about the collections within a given environment
        :param environment_id: this is the guid of a valid environment
        :return: json results of the collections in an environment
        """
        url_string = '/v1/environments/{0}/collections'.format(
            environment_id)
        return self.request(method='GET', url=url_string,
                            params={"version": self.version},
                            accept_json=True)
list_collections(discovery,environment_id)
# Out:
# {'collections': [{'collection_id': 'e2688c58-055d-487d-921f-a41c0dde6a55',
#    'configuration_id': '0806bbdd-6bef-4882-8ba9-093c37749337',
#    'created': '2018-05-04T11:46:47.697Z',
#    'description': '',
#    'language': 'en',
#    'name': 'MorganStanley',
#    'status': 'active',
#    'updated': '2018-06-17T19:18:25.451Z'},
#   {'collection_id': 'be9d4ddb-863c-4e5f-8a5e-aeee9fc73bc0',
#    'configuration_id': '4c720927-1619-479c-b5e0-c8c79c9803e6',
#    'created': '2018-07-05T17:39:47.081Z',
#    'description': None,
#    'language': 'en',
#    'name': 'Nature',
#    'status': 'active',
#    'updated': '2018-07-05T17:39:47.081Z'}]}
