# %% [markdown]
# # http://watson-developer-cloud.github.io/python-sdk/v1.0.2/apis/watson_developer_cloud.discovery_v1.html

# %%
import os
import sys
from watson_developer_cloud import DiscoveryV1
from dotenv import load_dotenv, find_dotenv
import json
import csv
import requests

# %%
try:
    load_dotenv(find_dotenv())
except IOError:
    print('warning: no .env file loaded')

# %%
discovery = DiscoveryV1(
              #url=os.getenv('DISCOVERY_URL'),
              username=os.getenv('DISCOVERY_USERNAME'),
              password=os.getenv('DISCOVERY_PASSWORD'),
              version="2018-03-05"
            )
environment_id = os.getenv('DISCOVERY_ENVIRONMENT_ID')
configuration_id = os.getenv('DISCOVERY_CONFIGURATION_ID')
collection_id =  os.getenv('DISCOVERY_COLLECTION_ID')
# collection_id = '6cd34257-ac8c-43d5-b62f-61e0e9732eca'
print(' environment_id :',environment_id,'\n configuration_id : ',configuration_id,'\n collection_id : ',collection_id)
# Out:
#  environment_id : fc71a276-5cb9-46a9-b24f-242588206648
#  configuration_id :  7b5331b5-7ecc-41dd-8646-bb532dc6bccb
#  collection_id :  5c8cc9b3-e8b7-409c-972c-053bf82e347c

# %%
#params = {}
#params["query"] = "%s" % ('What happens if you miss doses')
#discovery.query(environment_id=environment_id, collection_id=collection_id, count=1, natural_language_query='What measures should we take post floods?')

# %% [markdown]
# # Collect questions and get the response from discovery without relevancy training

# %%
with open ("/Users/rajeshgudikoti/Documents/rajesh/IBMDigital/Projects_docs/Indegene/questionair.txt") as questions:
    #open an output file to place the responses 
    filestr = "/Users/rajeshgudikoti/Documents/rajesh/IBMDigital/Projects_docs/Indegene/response-indegene.csv"
    of = open(filestr, "w")
    writer = csv.writer(of, delimiter=",")
    
    #go through each question in file and prepare Discovery query paramaters 
    for line in questions:
        question = line.replace("\n", "")
        params = {}
        params["query"] = "%s" % (question)
        print(question,' \t***\t ',params["query"])
        #params["return"] = {"_id","body","title"} #these fields may need to be updated depending on the content being used 
        #params["return"] = "_id" #these fields may need to be updated depending on the content being used 
        key = "return"
        params.setdefault(key, [])
        #a[key].append(1)
        params["return"].append("_id")
        params["return"].append("body")
        params["return"].append("title")
        params["count"] = 4 
        #print('params["return"] ',params["return"])
        #run Discovery query to get results from untrained service 
        result = discovery.query(environment_id=environment_id, collection_id=collection_id, query_options=params)
        
        #create a row for each query and results 
        result_list = [question.encode("utf8")]
        for resultDoc in result["results"]:
            #print('resultDoc_id',resultDoc['id'])
            
            #print("resultDoc.get('extracted_metadata').get('title') " ,resultDoc.get('extracted_metadata').get('title'))
            id = resultDoc["id"]
            print('\n resultDoc.extracted_metadata \n', resultDoc.get('extracted_metadata'))
            #if('extracted_metadata'["title"] in resultDoc):
            #if(resultDoc.get('extracted_metadata').get('title') is not 'None' or 'no title'):
            if('title' in resultDoc.get('extracted_metadata')):
                print('title --> ', resultDoc['extracted_metadata']['title'])
                title = resultDoc['extracted_metadata']['title'].encode("utf8")
            else:
                title = 'title not present'
            #if(resultDoc.get('html') is not 'None'):
            if('html' in resultDoc):
                body = resultDoc['html'].encode("utf8")
                print('html present in resultDoc \n-->')
            if('text' in resultDoc):
                body = resultDoc['text'].encode("utf8")
                print('text present in resultDoc \n-->')
            else:
                body ='body not present'
                print('body not present in resultDoc \n-->' , resultDoc)
            
            print('id \n', id, '\n title \n',title)
            
            #result_list.extend([id,title,body,' ']) #leave a space to enter a relevance label for each doc 
            result_list.extend([id,title,' '])
            
        #write the row to the file 
        writer.writerow(result_list)
    
    of.close()
    #print('result_list',result_list)
# Out:
# What happens if you miss doses  	***	  What happens if you miss doses
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-22', 'sha1': 'c600f43e7a34da25b83d1eb96714d3fd5443c965', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI_clopidogrel.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  d6aae77cbbd4ef194872f4b71497e6a2
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-18', 'sha1': '69559190b539b6cd1e2ecdce0390f606f6ffd3b7', 'author': 'Janhavi Dabir', 'filename': 'Discontinuation for surgery.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  4523137ed853c344d62b8ab4de81ec1e
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-22', 'sha1': '0e5553ef53cda01d9e5f8079722a72ee61c69502', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI_ASA.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  5e2c0d0a4c9f97d7b172d0a4019f81d6
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-18', 'sha1': '73bf45738195d9e48702676cad982a1b1e4927df', 'author': 'Janhavi Dabir', 'filename': 'Missed dose.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  c95997bd22352b12be390d1da577f9f4
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-18', 'sha1': '91d029268f785c07d9c7ab5d97f730b61cf1bd48', 'author': 'Janhavi Dabir', 'filename': 'Missed dose 15 mg twice daily.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  8c8c438d3e13e604af0a26c0111f5bb2
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-22', 'sha1': '7b81d6a94f28932b7d9d34215b5c01df6bf598ed', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI_NSAIDs.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  13237ceecaca321513040e9ed9dca656
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-22', 'sha1': '614af3b58fd45c5fdfcf9d4133d9e153e925b00a', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI_gastric_pH.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  ed590d8e4a828f3903588948a56a9253
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-22', 'sha1': 'f98de83e4b424f4e10821d784315deefe1039db4', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI_omeprazole.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  d1db29738b911f24133edf49859e17bc
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-22', 'sha1': 'd066ac6c57739629150b8974c7e7ff84a5b6a2a5', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI_SSRI.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  368f5998badbf2bd3f9c32b6879a11b2
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-22', 'sha1': 'ee67e4779478f11d4db1588987b239f2e075736e', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI_ranitidine.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  631a5efb71eccd1491013134836b7940
#  title
#  b'no title'
# Is it okay to miss a dose?  	***	  Is it okay to miss a dose?
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-22', 'sha1': 'c600f43e7a34da25b83d1eb96714d3fd5443c965', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI_clopidogrel.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  d6aae77cbbd4ef194872f4b71497e6a2
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-18', 'sha1': '69559190b539b6cd1e2ecdce0390f606f6ffd3b7', 'author': 'Janhavi Dabir', 'filename': 'Discontinuation for surgery.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  4523137ed853c344d62b8ab4de81ec1e
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-22', 'sha1': '0e5553ef53cda01d9e5f8079722a72ee61c69502', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI_ASA.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  5e2c0d0a4c9f97d7b172d0a4019f81d6
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-18', 'sha1': '73bf45738195d9e48702676cad982a1b1e4927df', 'author': 'Janhavi Dabir', 'filename': 'Missed dose.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  c95997bd22352b12be390d1da577f9f4
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-18', 'sha1': '91d029268f785c07d9c7ab5d97f730b61cf1bd48', 'author': 'Janhavi Dabir', 'filename': 'Missed dose 15 mg twice daily.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  8c8c438d3e13e604af0a26c0111f5bb2
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-22', 'sha1': '7b81d6a94f28932b7d9d34215b5c01df6bf598ed', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI_NSAIDs.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  13237ceecaca321513040e9ed9dca656
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-22', 'sha1': '614af3b58fd45c5fdfcf9d4133d9e153e925b00a', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI_gastric_pH.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  ed590d8e4a828f3903588948a56a9253
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-22', 'sha1': 'f98de83e4b424f4e10821d784315deefe1039db4', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI_omeprazole.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  d1db29738b911f24133edf49859e17bc
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-22', 'sha1': 'd066ac6c57739629150b8974c7e7ff84a5b6a2a5', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI_SSRI.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  368f5998badbf2bd3f9c32b6879a11b2
#  title
#  b'no title'
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-22', 'sha1': 'ee67e4779478f11d4db1588987b239f2e075736e', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI_ranitidine.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  631a5efb71eccd1491013134836b7940
#  title
#  b'no title'
# If someone is prescribed DrugX to be takent twice daily, and they miss a dose, should they double up that evening?  	***	  If someone is prescribed DrugX to be takent twice daily, and they miss a dose, should they double up that evening?
#
#  resultDoc.extracted_metadata
#  {'publicationdate': '2017-12-22', 'sha1': 'c600f43e7a34da25b83d1eb96714d3fd5443c965', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI
sha1': 'ee67e4779478f11d4db1588987b239f2e075736e', 'author': 'Sandeep Gantotti', 'filename': 'DrugX_DI_ranitidine.docx', 'file_type': 'word', 'title': 'no title'}
# title -->  no title
# html present in resultDoc
# -->
# text present in resultDoc
# -->
# id
#  631a5efb71eccd1491013134836b7940
#  title
#  b'no title'

# %% [markdown]
# # Upload Training Data

# %%
#function for posting to training data endpoint 
def training_post(discovery_training_path, training_obj):
    #training_json = json.dumps(training_obj)
    training_json = training_obj
    headers = {
        "content-type": "application/json",
        "Accept" : "text/plain"
        }
    auth = (os.getenv('DISCOVERY_USERNAME'), os.getenv('DISCOVERY_PASSWORD'))
    
    response = requests.request(method="POST",url=discovery_training_path,data=training_json,headers=headers,auth=auth)
    #print(response.status_code , response.reason, '\n', response.request, response.url,response.text)
    print('\n\n',response.reason,response.text,'\n\n')

# %%
#open the training file and create new training data objects
with open('/Users/rajeshgudikoti/Documents/rajesh/IBMDigital/Projects_docs/Indegene/response-indegene.csv','r') as training_doc:
    training_csv = csv.reader(training_doc, delimiter=',')    
    training_obj = {}
    training_obj["examples"] = []
    
    discovery_path = "https://gateway.watsonplatform.net/discovery/api/v1/environments/" + environment_id + "/collections/" + collection_id 
    discovery_training_path = discovery_path + "/training_data?version=2016-11-07"
    
    for row in training_csv:
        training_obj["natural_language_query"] = row[0]
        i = 1 
        print('\nrow ', row[0])
        training_obj["examples"]=[]
        #training_obj.fromkeys(["examples"])
        print('************\n traning example before loop*******', training_obj["examples"])
        for j in range(1,10):
            example_obj = {}
            
            #example_obj["relevance"] = row[i+3]
            # becuase we do not include body in result...see above cell
            example_obj["relevance"] = row[i+2]
            example_obj["document_id"] = row[i]
            
            print('example_obj.relevance', example_obj["relevance"])
            if (example_obj["relevance"]) is not ' ' or (example_obj["relevance"]) == 0:
                training_obj["examples"].append(example_obj)
            else:
                print('example_obj.relevance is zero or not specified')
                example_obj["relevance"] = 0
            #if (example_obj["relevance"]) != "0":
                #training_obj["examples"].append(example_obj)
            #else:
                #print('example_obj.relevance is zero')
            
            #training_obj["examples"].append(example_obj)
            
            #print('example_obj', example_obj)
            #training_obj["examples"] = example_obj
            i = i + 3
            
            print('\n\nrelevance object ',example_obj["relevance"] )
            #print('document id ', example_obj["document_id"])
            #print('traning example', training_obj["examples"])
            print('***** training_obj', json.dumps(training_obj))
        
            #send the training data to the discovery service 
        response = training_post(discovery_training_path, json.dumps(training_obj))
            #print(response.status_code , response.reason, '\n', response.request, response.url,response.text)
            
            #print('traning example', training_obj["examples"])
# Out:
# row  b'What happens if you miss doses'
# ************
#  traning example before loop******* []
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}], "natural_language_query": "b'What happens if you miss doses'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}], "natural_language_query": "b'What happens if you miss doses'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}], "natural_language_query": "b'What happens if you miss doses'"}
# example_obj.relevance 5
#
#
# relevance object  5
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}], "natural_language_query": "b'What happens if you miss doses'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "0", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}], "natural_language_query": "b'What happens if you miss doses'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "0", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}], "natural_language_query": "b'What happens if you miss doses'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "0", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}], "natural_language_query": "b'What happens if you miss doses'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "0", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "1", "document_id": "d1db29738b911f24133edf49859e17bc"}], "natural_language_query": "b'What happens if you miss doses'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "0", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "1", "document_id": "d1db29738b911f24133edf49859e17bc"}, {"relevance": "0", "document_id": "368f5998badbf2bd3f9c32b6879a11b2"}], "natural_language_query": "b'What happens if you miss doses'"}
#
#
#  Created {"natural_language_query":"b'What happens if you miss doses'","filter":"","examples":[{"document_id":"d6aae77cbbd4ef194872f4b71497e6a2","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:29.493Z","updated":"2018-08-22T16:48:29.526Z"},{"document_id":"4523137ed853c344d62b8ab4de81ec1e","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:29.493Z","updated":"2018-08-22T16:48:29.530Z"},{"document_id":"5e2c0d0a4c9f97d7b172d0a4019f81d6","cross_reference":"","relevance":1,"created":"2018-08-22T16:48:29.493Z","updated":"2018-08-22T16:48:29.534Z"},{"document_id":"c95997bd22352b12be390d1da577f9f4","cross_reference":"","relevance":5,"created":"2018-08-22T16:48:29.493Z","updated":"2018-08-22T16:48:29.538Z"},{"document_id":"8c8c438d3e13e604af0a26c0111f5bb2","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:29.493Z","updated":"2018-08-22T16:48:29.543Z"},{"document_id":"13237ceecaca321513040e9ed9dca656","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:29.493Z","updated":"2018-08-22T16:48:29.547Z"},{"document_id":"ed590d8e4a828f3903588948a56a9253","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:29.493Z","updated":"2018-08-22T16:48:29.551Z"},{"document_id":"d1db29738b911f24133edf49859e17bc","cross_reference":"","relevance":1,"created":"2018-08-22T16:48:29.493Z","updated":"2018-08-22T16:48:29.555Z"},{"document_id":"368f5998badbf2bd3f9c32b6879a11b2","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:29.493Z","updated":"2018-08-22T16:48:29.560Z"}],"query_id":"e25f8c4ae700cdfc46d57af73507922585382a13","created":"2018-08-22T16:48:29.494Z","updated":"2018-08-22T16:48:29.494Z"}
#
#
#
# row  b'Is it okay to miss a dose?'
# ************
#  traning example before loop******* []
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}], "natural_language_query": "b'Is it okay to miss a dose?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}], "natural_language_query": "b'Is it okay to miss a dose?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}], "natural_language_query": "b'Is it okay to miss a dose?'"}
# example_obj.relevance 5
#
#
# relevance object  5
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}], "natural_language_query": "b'Is it okay to miss a dose?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "0", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}], "natural_language_query": "b'Is it okay to miss a dose?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "0", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}], "natural_language_query": "b'Is it okay to miss a dose?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "0", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}], "natural_language_query": "b'Is it okay to miss a dose?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "0", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "1", "document_id": "d1db29738b911f24133edf49859e17bc"}], "natural_language_query": "b'Is it okay to miss a dose?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "0", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "1", "document_id": "d1db29738b911f24133edf49859e17bc"}, {"relevance": "0", "document_id": "368f5998badbf2bd3f9c32b6879a11b2"}], "natural_language_query": "b'Is it okay to miss a dose?'"}
#  Created {"natural_language_query":"b'Is it okay to miss a dose?'","filter":"","examples":[{"document_id":"d6aae77cbbd4ef194872f4b71497e6a2","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:30.366Z","updated":"2018-08-22T16:48:30.397Z"},{"document_id":"4523137ed853c344d62b8ab4de81ec1e","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:30.366Z","updated":"2018-08-22T16:48:30.401Z"},{"document_id":"5e2c0d0a4c9f97d7b172d0a4019f81d6","cross_reference":"","relevance":1,"created":"2018-08-22T16:48:30.366Z","updated":"2018-08-22T16:48:30.406Z"},{"document_id":"c95997bd22352b12be390d1da577f9f4","cross_reference":"","relevance":5,"created":"2018-08-22T16:48:30.366Z","updated":"2018-08-22T16:48:30.410Z"},{"document_id":"8c8c438d3e13e604af0a26c0111f5bb2","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:30.366Z","updated":"2018-08-22T16:48:30.414Z"},{"document_id":"13237ceecaca321513040e9ed9dca656","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:30.366Z","updated":"2018-08-22T16:48:30.418Z"},{"document_id":"ed590d8e4a828f3903588948a56a9253","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:30.366Z","updated":"2018-08-22T16:48:30.423Z"},{"document_id":"d1db29738b911f24133edf49859e17bc","cross_reference":"","relevance":1,"created":"2018-08-22T16:48:30.366Z","updated":"2018-08-22T16:48:30.427Z"},{"document_id":"368f5998badbf2bd3f9c32b6879a11b2","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:30.366Z","updated":"2018-08-22T16:48:30.431Z"}],"query_id":"31ac58da5db130efdcbf32886ba65d73835ea501","created":"2018-08-22T16:48:30.368Z","updated":"2018-08-22T16:48:30.368Z"}
#
#
#
# row  b'If someone is prescribed DrugX to be takent twice daily, and they miss a dose, should they double up that evening?'
# ************
#  traning example before loop******* []
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}], "natural_language_query": "b'If someone is prescribed DrugX to be takent twice daily, and they miss a dose, should they double up that evening?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}], "natural_language_query": "b'If someone is prescribed DrugX to be takent twice daily, and they miss a dose, should they double up that evening?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}], "natural_language_query": "b'If someone is prescribed DrugX to be takent twice daily, and they miss a dose, should they double up that evening?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}], "natural_language_query": "b'If someone is prescribed DrugX to be takent twice daily, and they miss a dose, should they double up that evening?'"}
# example_obj.relevance 5
#
#
# relevance object  5
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "5", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}], "natural_language_query": "b'If someone is prescribed DrugX to be takent twice daily, and they miss a dose, should they double up that evening?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "5", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}], "natural_language_query": "b'If someone is prescribed DrugX to be takent twice daily, and they miss a dose, should they double up that evening?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "5", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}], "natural_language_query": "b'If someone is prescribed DrugX to be takent twice daily, and they miss a dose, should they double up that evening?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "5", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "1", "document_id": "d1db29738b911f24133edf49859e17bc"}], "natural_language_query": "b'If someone is prescribed DrugX to be takent twice daily, and they miss a dose, should they double up that evening?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "5", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "1", "document_id": "d1db29738b911f24133edf49859e17bc"}, {"relevance": "0", "document_id": "368f5998badbf2bd3f9c32b6879a11b2"}], "natural_language_query": "b'If someone is prescribed DrugX to be takent twice daily, and they miss a dose, should they double up that evening?'"}
#
#
#  Created {"natural_language_query":"b'If someone is prescribed DrugX to be takent twice daily, and they miss a dose, should they double up that evening?'","filter":"","examples":[{"document_id":"d6aae77cbbd4ef194872f4b71497e6a2","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:31.416Z","updated":"2018-08-22T16:48:31.441Z"},{"document_id":"4523137ed853c344d62b8ab4de81ec1e","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:31.416Z","updated":"2018-08-22T16:48:31.443Z"},{"document_id":"5e2c0d0a4c9f97d7b172d0a4019f81d6","cross_reference":"","relevance":1,"created":"2018-08-22T16:48:31.416Z","updated":"2018-08-22T16:48:31.446Z"},{"document_id":"c95997bd22352b12be390d1da577f9f4","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:31.416Z","updated":"2018-08-22T16:48:31.448Z"},{"document_id":"8c8c438d3e13e604af0a26c0111f5bb2","cross_reference":"","relevance":5,"created":"2018-08-22T16:48:31.416Z","updated":"2018-08-22T16:48:31.451Z"},{"document_id":"13237ceecaca321513040e9ed9dca656","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:31.416Z","updated":"2018-08-22T16:48:31.453Z"},{"document_id":"ed590d8e4a828f3903588948a56a9253","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:31.416Z","updated":"2018-08-22T16:48:31.456Z"},{"document_id":"d1db29738b911f24133edf49859e17bc","cross_reference":"","relevance":1,"created":"2018-08-22T16:48:31.416Z","updated":"2018-08-22T16:48:31.458Z"},{"document_id":"368f5998badbf2bd3f9c32b6879a11b2","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:31.416Z","updated":"2018-08-22T16:48:31.461Z"}],"query_id":"f09bbdfacdbacef3ff61bb5d23ab1ad95c21a9fb","created":"2018-08-22T16:48:31.420Z","updated":"2018-08-22T16:48:31.420Z"}
#
#
#
# row  b'Should I take my second dose of DrugX 15mg today if I was late taking my very first dose?'
# ************
#  traning example before loop******* []
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}], "natural_language_query": "b'Should I take my second dose of DrugX 15mg today if I was late taking my very first dose?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}], "natural_language_query": "b'Should I take my second dose of DrugX 15mg today if I was late taking my very first dose?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}], "natural_language_query": "b'Should I take my second dose of DrugX 15mg today if I was late taking my very first dose?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}], "natural_language_query": "b'Should I take my second dose of DrugX 15mg today if I was late taking my very first dose?'"}
# example_obj.relevance 5
#
#
# relevance object  5
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "5", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}], "natural_language_query": "b'Should I take my second dose of DrugX 15mg today if I was late taking my very first dose?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "5", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}], "natural_language_query": "b'Should I take my second dose of DrugX 15mg today if I was late taking my very first dose?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "5", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}], "natural_language_query": "b'Should I take my second dose of DrugX 15mg today if I was late taking my very first dose?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "5", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "1", "document_id": "d1db29738b911f24133edf49859e17bc"}], "natural_language_query": "b'Should I take my second dose of DrugX 15mg today if I was late taking my very first dose?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "5", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "1", "document_id": "d1db29738b911f24133edf49859e17bc"}, {"relevance": "0", "document_id": "368f5998badbf2bd3f9c32b6879a11b2"}], "natural_language_query": "b'Should I take my second dose of DrugX 15mg today if I was late taking my very first dose?'"}
#  Created {"natural_language_query":"b'Should I take my second dose of DrugX 15mg today if I was late taking my very first dose?'","filter":"","examples":[{"document_id":"d6aae77cbbd4ef194872f4b71497e6a2","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:32.242Z","updated":"2018-08-22T16:48:32.271Z"},{"document_id":"4523137ed853c344d62b8ab4de81ec1e","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:32.242Z","updated":"2018-08-22T16:48:32.275Z"},{"document_id":"5e2c0d0a4c9f97d7b172d0a4019f81d6","cross_reference":"","relevance":1,"created":"2018-08-22T16:48:32.242Z","updated":"2018-08-22T16:48:32.279Z"},{"document_id":"c95997bd22352b12be390d1da577f9f4","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:32.242Z","updated":"2018-08-22T16:48:32.283Z"},{"document_id":"8c8c438d3e13e604af0a26c0111f5bb2","cross_reference":"","relevance":5,"created":"2018-08-22T16:48:32.242Z","updated":"2018-08-22T16:48:32.287Z"},{"document_id":"13237ceecaca321513040e9ed9dca656","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:32.242Z","updated":"2018-08-22T16:48:32.291Z"},{"document_id":"ed590d8e4a828f3903588948a56a9253","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:32.242Z","updated":"2018-08-22T16:48:32.295Z"},{"document_id":"d1db29738b911f24133edf49859e17bc","cross_reference":"","relevance":1,"created":"2018-08-22T16:48:32.242Z","updated":"2018-08-22T16:48:32.299Z"},{"document_id":"368f5998badbf2bd3f9c32b6879a11b2","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:32.242Z","updated":"2018-08-22T16:48:32.303Z"}],"query_id":"3a34a679a723c01213be3a9988225875286fac78","created":"2018-08-22T16:48:32.243Z","updated":"2018-08-22T16:48:32.243Z"}
#
#
#
# row  b'What happens if I miss a dose'
# ************
#  traning example before loop******* []
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}], "natural_language_query": "b'What happens if I miss a dose'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}], "natural_language_query": "b'What happens if I miss a dose'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}], "natural_language_query": "b'What happens if I miss a dose'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}], "natural_language_query": "b'What happens if I miss a dose'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}], "natural_language_query": "b'What happens if I miss a dose'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}], "natural_language_query": "b'What happens if I miss a dose'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}], "natural_language_query": "b'What happens if I miss a dose'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "1", "document_id": "d1db29738b911f24133edf49859e17bc"}], "natural_language_query": "b'What happens if I miss a dose'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "0", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "1", "document_id": "d1db29738b911f24133edf49859e17bc"}, {"relevance": "0", "document_id": "368f5998badbf2bd3f9c32b6879a11b2"}], "natural_language_query": "b'What happens if I miss a dose'"}
#
#
#  Created {"natural_language_query":"b'What happens if I miss a dose'","filter":"","examples":[{"document_id":"d6aae77cbbd4ef194872f4b71497e6a2","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:33.139Z","updated":"2018-08-22T16:48:33.171Z"},{"document_id":"4523137ed853c344d62b8ab4de81ec1e","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:33.139Z","updated":"2018-08-22T16:48:33.175Z"},{"document_id":"5e2c0d0a4c9f97d7b172d0a4019f81d6","cross_reference":"","relevance":1,"created":"2018-08-22T16:48:33.139Z","updated":"2018-08-22T16:48:33.179Z"},{"document_id":"c95997bd22352b12be390d1da577f9f4","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:33.139Z","updated":"2018-08-22T16:48:33.184Z"},{"document_id":"8c8c438d3e13e604af0a26c0111f5bb2","cross_reference":"","relevance":1,"created":"2018-08-22T16:48:33.139Z","updated":"2018-08-22T16:48:33.188Z"},{"document_id":"13237ceecaca321513040e9ed9dca656","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:33.139Z","updated":"2018-08-22T16:48:33.192Z"},{"document_id":"ed590d8e4a828f3903588948a56a9253","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:33.139Z","updated":"2018-08-22T16:48:33.197Z"},{"document_id":"d1db29738b911f24133edf49859e17bc","cross_reference":"","relevance":1,"created":"2018-08-22T16:48:33.139Z","updated":"2018-08-22T16:48:33.201Z"},{"document_id":"368f5998badbf2bd3f9c32b6879a11b2","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:33.139Z","updated":"2018-08-22T16:48:33.205Z"}],"query_id":"688253620b58af661f26ef414ce32c7173138e3e","created":"2018-08-22T16:48:33.141Z","updated":"2018-08-22T16:48:33.141Z"}
#
#
#
# row  b'If someone taking DrugX missed their dose yesterday what should they do?'
# ************
#  traning example before loop******* []
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}], "natural_language_query": "b'If someone taking DrugX missed their dose yesterday what should they do?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}], "natural_language_query": "b'If someone taking DrugX missed their dose yesterday what should they do?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}], "natural_language_query": "b'If someone taking DrugX missed their dose yesterday what should they do?'"}
# example_obj.relevance 5
#
#
# relevance object  5
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}], "natural_language_query": "b'If someone taking DrugX missed their dose yesterday what should they do?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}], "natural_language_query": "b'If someone taking DrugX missed their dose yesterday what should they do?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}], "natural_language_query": "b'If someone taking DrugX missed their dose yesterday what should they do?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}], "natural_language_query": "b'If someone taking DrugX missed their dose yesterday what should they do?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "1", "document_id": "d1db29738b911f24133edf49859e17bc"}], "natural_language_query": "b'If someone taking DrugX missed their dose yesterday what should they do?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "1", "document_id": "d1db29738b911f24133edf49859e17bc"}, {"relevance": "0", "document_id": "368f5998badbf2bd3f9c32b6879a11b2"}], "natural_language_query": "b'If someone taking DrugX missed their dose yesterday what should they do?'"}
#  Created {"natural_language_query":"b'If someone taking DrugX missed their dose yesterday what should they do?'","filter":"","examples":[{"document_id":"d6aae77cbbd4ef194872f4b71497e6a2","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:34.219Z","updated":"2018-08-22T16:48:34.249Z"},{"document_id":"4523137ed853c344d62b8ab4de81ec1e","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:34.219Z","updated":"2018-08-22T16:48:34.254Z"},{"document_id":"5e2c0d0a4c9f97d7b172d0a4019f81d6","cross_reference":"","relevance":1,"created":"2018-08-22T16:48:34.219Z","updated":"2018-08-22T16:48:34.258Z"},{"document_id":"c95997bd22352b12be390d1da577f9f4","cross_reference":"","relevance":5,"created":"2018-08-22T16:48:34.219Z","updated":"2018-08-22T16:48:34.262Z"},{"document_id":"8c8c438d3e13e604af0a26c0111f5bb2","cross_reference":"","relevance":1,"created":"2018-08-22T16:48:34.219Z","updated":"2018-08-22T16:48:34.266Z"},{"document_id":"13237ceecaca321513040e9ed9dca656","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:34.219Z","updated":"2018-08-22T16:48:34.271Z"},{"document_id":"ed590d8e4a828f3903588948a56a9253","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:34.219Z","updated":"2018-08-22T16:48:34.275Z"},{"document_id":"d1db29738b911f24133edf49859e17bc","cross_reference":"","relevance":1,"created":"2018-08-22T16:48:34.219Z","updated":"2018-08-22T16:48:34.279Z"},{"document_id":"368f5998badbf2bd3f9c32b6879a11b2","cross_reference":"","relevance":0,"created":"2018-08-22T16:48:34.219Z","updated":"2018-08-22T16:48:34.283Z"}],"query_id":"f0ec5c9c369cdb6ddf28c568de80ab0840a10575","created":"2018-08-22T16:48:34.220Z","updated":"2018-08-22T16:48:34.220Z"}
#
#
#
# row  b'What is the correct course of action if dose of DrugX is forgotten in the morning?'
# ************
#  traning example before loop******* []
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}], "natural_language_query": "b'What is the correct course of action if dose of DrugX is forgotten in the morning?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}], "natural_language_query": "b'What is the correct course of action if dose of DrugX is forgotten in the morning?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}], "natural_language_query": "b'What is the correct course of action if dose of DrugX is forgotten in the morning?'"}
# example_obj.relevance 5
#
#
# relevance object  5
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}], "natural_language_query": "b'What is the correct course of action if dose of DrugX is forgotten in the morning?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}], "natural_language_query": "b'What is the correct course of action if dose of DrugX is forgotten in the morning?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}], "natural_language_query": "b'What is the correct course of action if dose of DrugX is forgotten in the morning?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}], "natural_language_query": "b'What is the correct course of action if dose of DrugX is forgotten in the morning?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "1", "document_id": "d1db29738b911f24133edf49859e17bc"}], "natural_language_query": "b'What is the correct course of action if dose of DrugX is forgotten in the morning?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "0", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "0", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "1", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "0", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "0", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "1", "document_id": "d1db29738b911f24133edf49859e17bc"}, {"relevance": "0", "document_id": "368f5998badbf2bd3f9c32b6879a11b2"}], "natural_language_query": "b'What is the correct course of action if dose of DrugX is forgotten in the morning?'"}
#
#
#  Created {"natural_language_query":"b'What is the correct course of action if dose of DrugX is forgotten in the morning?'","filter":"","examples":[{"document_id":"d6aae77cbbd4ef194872f4b71497e6a2","cross_reference":"","relevance":0,"created":"2018-08-22T16:48
":"2018-08-22T16:50:11.094Z","updated":"2018-08-22T16:50:11.153Z"},{"document_id":"13237ceecaca321513040e9ed9dca656","cross_reference":"","relevance":2,"created":"2018-08-22T16:50:11.094Z","updated":"2018-08-22T16:50:11.159Z"},{"document_id":"ed590d8e4a828f3903588948a56a9253","cross_reference":"","relevance":2,"created":"2018-08-22T16:50:11.094Z","updated":"2018-08-22T16:50:11.165Z"},{"document_id":"d1db29738b911f24133edf49859e17bc","cross_reference":"","relevance":2,"created":"2018-08-22T16:50:11.094Z","updated":"2018-08-22T16:50:11.170Z"},{"document_id":"368f5998badbf2bd3f9c32b6879a11b2","cross_reference":"","relevance":3,"created":"2018-08-22T16:50:11.094Z","updated":"2018-08-22T16:50:11.176Z"}],"query_id":"c72d1dde31d36578ef988e5a6874e714bc210100","created":"2018-08-22T16:50:11.096Z","updated":"2018-08-22T16:50:11.096Z"}
#
#
#
# row  b'If someone forgot to take DrugX in the evening, took the medication the next morning when they remembered, when should the next dose be taken?'
# ************
#  traning example before loop******* []
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}], "natural_language_query": "b'If someone forgot to take DrugX in the evening, took the medication the next morning when they remembered, when should the next dose be taken?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}], "natural_language_query": "b'If someone forgot to take DrugX in the evening, took the medication the next morning when they remembered, when should the next dose be taken?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "0", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}], "natural_language_query": "b'If someone forgot to take DrugX in the evening, took the medication the next morning when they remembered, when should the next dose be taken?'"}
# example_obj.relevance 5
#
#
# relevance object  5
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "0", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}], "natural_language_query": "b'If someone forgot to take DrugX in the evening, took the medication the next morning when they remembered, when should the next dose be taken?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "0", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}], "natural_language_query": "b'If someone forgot to take DrugX in the evening, took the medication the next morning when they remembered, when should the next dose be taken?'"}
# example_obj.relevance 2
#
#
# relevance object  2
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "0", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "2", "document_id": "13237ceecaca321513040e9ed9dca656"}], "natural_language_query": "b'If someone forgot to take DrugX in the evening, took the medication the next morning when they remembered, when should the next dose be taken?'"}
# example_obj.relevance 2
#
#
# relevance object  2
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "0", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "2", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "2", "document_id": "ed590d8e4a828f3903588948a56a9253"}], "natural_language_query": "b'If someone forgot to take DrugX in the evening, took the medication the next morning when they remembered, when should the next dose be taken?'"}
# example_obj.relevance 2
#
#
# relevance object  2
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "0", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "2", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "2", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "2", "document_id": "d1db29738b911f24133edf49859e17bc"}], "natural_language_query": "b'If someone forgot to take DrugX in the evening, took the medication the next morning when they remembered, when should the next dose be taken?'"}
# example_obj.relevance 3
#
#
# relevance object  3
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "0", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "2", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "2", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "2", "document_id": "d1db29738b911f24133edf49859e17bc"}, {"relevance": "3", "document_id": "368f5998badbf2bd3f9c32b6879a11b2"}], "natural_language_query": "b'If someone forgot to take DrugX in the evening, took the medication the next morning when they remembered, when should the next dose be taken?'"}
#
#
#  Created {"natural_language_query":"b'If someone forgot to take DrugX in the evening, took the medication the next morning when they remembered, when should the next dose be taken?'","filter":"","examples":[{"document_id":"d6aae77cbbd4ef194872f4b71497e6a2","cross_reference":"","relevance":1,"created":"2018-08-22T16:50:12.058Z","updated":"2018-08-22T16:50:12.083Z"},{"document_id":"4523137ed853c344d62b8ab4de81ec1e","cross_reference":"","relevance":1,"created":"2018-08-22T16:50:12.058Z","updated":"2018-08-22T16:50:12.086Z"},{"document_id":"5e2c0d0a4c9f97d7b172d0a4019f81d6","cross_reference":"","relevance":0,"created":"2018-08-22T16:50:12.058Z","updated":"2018-08-22T16:50:12.089Z"},{"document_id":"c95997bd22352b12be390d1da577f9f4","cross_reference":"","relevance":5,"created":"2018-08-22T16:50:12.058Z","updated":"2018-08-22T16:50:12.092Z"},{"document_id":"8c8c438d3e13e604af0a26c0111f5bb2","cross_reference":"","relevance":1,"created":"2018-08-22T16:50:12.058Z","updated":"2018-08-22T16:50:12.096Z"},{"document_id":"13237ceecaca321513040e9ed9dca656","cross_reference":"","relevance":2,"created":"2018-08-22T16:50:12.058Z","updated":"2018-08-22T16:50:12.099Z"},{"document_id":"ed590d8e4a828f3903588948a56a9253","cross_reference":"","relevance":2,"created":"2018-08-22T16:50:12.058Z","updated":"2018-08-22T16:50:12.102Z"},{"document_id":"d1db29738b911f24133edf49859e17bc","cross_reference":"","relevance":2,"created":"2018-08-22T16:50:12.058Z","updated":"2018-08-22T16:50:12.105Z"},{"document_id":"368f5998badbf2bd3f9c32b6879a11b2","cross_reference":"","relevance":3,"created":"2018-08-22T16:50:12.058Z","updated":"2018-08-22T16:50:12.108Z"}],"query_id":"ac75a44f6154fee57365dd0ccaf074f6c2c63f42","created":"2018-08-22T16:50:12.061Z","updated":"2018-08-22T16:50:12.061Z"}
#
#
#
# row  b'What should someone do if they forget to take their DrugX?'
# ************
#  traning example before loop******* []
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}], "natural_language_query": "b'What should someone do if they forget to take their DrugX?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}], "natural_language_query": "b'What should someone do if they forget to take their DrugX?'"}
# example_obj.relevance 0
#
#
# relevance object  0
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "0", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}], "natural_language_query": "b'What should someone do if they forget to take their DrugX?'"}
# example_obj.relevance 5
#
#
# relevance object  5
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "0", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}], "natural_language_query": "b'What should someone do if they forget to take their DrugX?'"}
# example_obj.relevance 1
#
#
# relevance object  1
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "0", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}], "natural_language_query": "b'What should someone do if they forget to take their DrugX?'"}
# example_obj.relevance 2
#
#
# relevance object  2
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "0", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "2", "document_id": "13237ceecaca321513040e9ed9dca656"}], "natural_language_query": "b'What should someone do if they forget to take their DrugX?'"}
# example_obj.relevance 2
#
#
# relevance object  2
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "0", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "2", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "2", "document_id": "ed590d8e4a828f3903588948a56a9253"}], "natural_language_query": "b'What should someone do if they forget to take their DrugX?'"}
# example_obj.relevance 2
#
#
# relevance object  2
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "0", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "2", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "2", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "2", "document_id": "d1db29738b911f24133edf49859e17bc"}], "natural_language_query": "b'What should someone do if they forget to take their DrugX?'"}
# example_obj.relevance 3
#
#
# relevance object  3
# ***** training_obj {"examples": [{"relevance": "1", "document_id": "d6aae77cbbd4ef194872f4b71497e6a2"}, {"relevance": "1", "document_id": "4523137ed853c344d62b8ab4de81ec1e"}, {"relevance": "0", "document_id": "5e2c0d0a4c9f97d7b172d0a4019f81d6"}, {"relevance": "5", "document_id": "c95997bd22352b12be390d1da577f9f4"}, {"relevance": "1", "document_id": "8c8c438d3e13e604af0a26c0111f5bb2"}, {"relevance": "2", "document_id": "13237ceecaca321513040e9ed9dca656"}, {"relevance": "2", "document_id": "ed590d8e4a828f3903588948a56a9253"}, {"relevance": "2", "document_id": "d1db29738b911f24133edf49859e17bc"}, {"relevance": "3", "document_id": "368f5998badbf2bd3f9c32b6879a11b2"}], "natural_language_query": "b'What should someone do if they forget to take their DrugX?'"}
#  Created {"natural_language_query":"b'What should someone do if they forget to take their DrugX?'","filter":"","examples":[{"document_id":"d6aae77cbbd4ef194872f4b71497e6a2","cross_reference":"","relevance":1,"created":"2018-08-22T16:50:12.958Z","updated":"2018-08-22T16:50:12.995Z"},{"document_id":"4523137ed853c344d62b8ab4de81ec1e","cross_reference":"","relevance":1,"created":"2018-08-22T16:50:12.958Z","updated":"2018-08-22T16:50:13.001Z"},{"document_id":"5e2c0d0a4c9f97d7b172d0a4019f81d6","cross_reference":"","relevance":0,"created":"2018-08-22T16:50:12.958Z","updated":"2018-08-22T16:50:13.006Z"},{"document_id":"c95997bd22352b12be390d1da577f9f4","cross_reference":"","relevance":5,"created":"2018-08-22T16:50:12.958Z","updated":"2018-08-22T16:50:13.012Z"},{"document_id":"8c8c438d3e13e604af0a26c0111f5bb2","cross_reference":"","relevance":1,"created":"2018-08-22T16:50:12.958Z","updated":"2018-08-22T16:50:13.017Z"},{"document_id":"13237ceecaca321513040e9ed9dca656","cross_reference":"","relevance":2,"created":"2018-08-22T16:50:12.958Z","updated":"2018-08-22T16:50:13.023Z"},{"document_id":"ed590d8e4a828f3903588948a56a9253","cross_reference":"","relevance":2,"created":"2018-08-22T16:50:12.958Z","updated":"2018-08-22T16:50:13.029Z"},{"document_id":"d1db29738b911f24133edf49859e17bc","cross_reference":"","relevance":2,"created":"2018-08-22T16:50:12.958Z","updated":"2018-08-22T16:50:13.034Z"},{"document_id":"368f5998badbf2bd3f9c32b6879a11b2","cross_reference":"","relevance":3,"created":"2018-08-22T16:50:12.958Z","updated":"2018-08-22T16:50:13.040Z"}],"query_id":"597568ff0a3ebc4eba5fe4dea201f6d6b84be95d","created":"2018-08-22T16:50:12.960Z","updated":"2018-08-22T16:50:12.960Z"}

# %% [markdown]
# # Query post relevance training

# %%
discovery.query(environment_id, collection_id, filter=None, query=None, natural_language_query='What happens if you miss doses', 
                passages=True, 
      aggregation=None, count=None, return_fields=None, offset=None, sort=None, highlight=None, 
      passages_fields=None, passages_count=None, passages_characters=None, deduplicate=None, deduplicate_field=None)
# Out:
# {'matching_results': 8,
#  'passages': [{'document_id': 'c95997bd22352b12be390d1da577f9f4',
#    'end_offset': 552,
#    'field': 'text',
#    'passage_score': 8.69685660825127,
#    'passage_text': 'The patient should continue with the regular 15 mg twice daily intake as recommended on the following day.\n\nFor patients receiving 20 mg, 15 mg or 10 mg once daily: The patient should take the missed Xarelto® dose immediately.',
#    'start_offset': 326},
#   {'document_id': 'c95997bd22352b12be390d1da577f9f4',
#    'end_offset': 964,
#    'field': 'html',
#    'passage_score': 8.544146220046683,
#    'passage_text': 'day.</p>\n<p dir="ltr">For patients receiving 20 mg, 15 mg or 10 mg once daily: The patient should take the missed Xarelto® dose immediately.</p>\n</div>\n\n</body></html>',
#    'start_offset': 797},
#   {'document_id': 'd6aae77cbbd4ef194872f4b71497e6a2',
#    'end_offset': 796,
#    'field': 'html',
#    'passage_score': 4.657042810830453,
#    'passage_text': ', however, clopidogrel (300 mg loading dose followed by 75 mg daily maintenance dose) and DRUGX (15 mg single dose) administration in healthy subjects resulted in an increase in bleeding time to 45',
#    'start_offset': 599},
#   {'document_id': 'd6aae77cbbd4ef194872f4b71497e6a2',
#    'end_offset': 385,
#    'field': 'text',
#    'passage_score': 4.657042810830453,
#    'passage_text': 'Coadministration of clopidogrel and DRUGX did not affect the pharmacokinetics of either drug, however, clopidogrel (300 mg loading dose followed by 75 mg daily maintenance dose) and DRUGX (15 mg single dose) administration in healthy subjects resulted',
#    'start_offset': 134},
#   {'document_id': 'c95997bd22352b12be390d1da577f9f4',
#    'end_offset': 256,
#    'field': 'text',
#    'passage_score': 4.115854707884658,
#    'passage_text': 'no title\n\nIf a dose of Xarelto® is not taken at the scheduled time, administer the dose as soon as possible on the same day.\n\nFor patients receiving 15 mg twice daily: The patient should take Xarelto® immediately to ensure intake of 30 mg Xarelto® per day.',
#    'start_offset': 0},
#   {'document_id': '8c8c438d3e13e604af0a26c0111f5bb2',
#    'end_offset': 249,
#    'field': 'text',
#    'passage_score': 4.115854707884658,
#    'passage_text': 'no title\n\nIf a dose of DrugX® is not taken at the scheduled time, administer the dose as soon as possible on the same day. For patients receiving 15 mg twice daily, the patient should take DrugX® immediately to ensure intake of 30 mg DrugX® per day.',
#    'start_offset': 0},
#   {'document_id': '5e2c0d0a4c9f97d7b172d0a4019f81d6',
#    'end_offset': 718,
#    'field': 'html',
#    'passage_score': 3.5510522708687553,
#    'passage_text': 'fibrillation study, aspirin at doses &lt; 100mg was an independent risk factor for bleeding.</p>\n</div>\n\n</body></html>',
#    'start_offset': 599},
#   {'document_id': '5e2c0d0a4c9f97d7b172d0a4019f81d6',
#    'end_offset': 316,
#    'field': 'text',
#    'passage_score': 3.5510522708687553,
#    'passage_text': 'Aspirin did not affect the pharmacokinetics of rivaroxaban, however, in the pivotal atrial fibrillation study, aspirin at doses < 100mg was an independent risk factor for bleeding.',
#    'start_offset': 136},
#   {'document_id': 'e86a7d854bfeb6180e6c1cc584bcfa9f',
#    'end_offset': 317,
#    'field': 'text',
#    'passage_score': 3.5051878566502372,
#    'passage_text': 'Warfarin did not alter the pharmacokinetics of rivaroxaban, however single doses of warfarin 15 mg and DrugX (5mg) resulted an additive effect on factor Xa inhibition and PT.',
#    'start_offset': 143},
#   {'document_id': 'd1db29738b911f24133edf49859e17bc',
#    'end_offset': 157,
#    'field': 'text',
#    'passage_score': 3.2337106917026466,
#    'passage_text': 'no title\n\nCoadministration of DrugX (30 mg single dose) with omeprazole (40 mg once daily) did not affect the bioavailability and exposure of rivaroxaban.\n\n\xa0',
#    'start_offset': 0}],
#  'results': [{'enriched_text': {'categories': [{'label': '/food and drink/food/fruits and vegetables',
#       'score': 0.576415},
#      {'label': '/science/medicine', 'score': 0.552624},
#      {'label': '/science/medicine/pediatrics', 'score': 0.458426}],
#     'concepts': [{'dbpedia_resource': 'http://dbpedia.org/resource/Patient',
#       'relevance': 0.938227,
#       'text': 'Patient'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Patience_(disambiguation)',
#       'relevance': 0.811842,
#       'text': 'Patience'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Following',
#       'relevance': 0.644493,
#       'text': 'Following'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/English-language_films',
#       'relevance': 0.62619,
#       'text': 'English-language films'}],
#     'entities': [{'count': 3,
#       'relevance': 0.01,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '15 mg',
#       'type': 'Quantity'},
#      {'count': 1,
#       'relevance': 0.01,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': 'two 15 mg',
#       'type': 'Quantity'},
#      {'count': 1,
#       'relevance': 0.01,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '10 mg',
#       'type': 'Quantity'},
#      {'count': 1,
#       'relevance': 0.01,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '20 mg',
#       'type': 'Quantity'},
#      {'count': 1,
#       'relevance': 0.01,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '30 mg',
#       'type': 'Quantity'}],
#     'sentiment': {'document': {'label': 'negative', 'score': -0.123769}}},
#    'extracted_metadata': {'author': 'Janhavi Dabir',
#     'file_type': 'word',
#     'filename': 'Missed dose.docx',
#     'publicationdate': '2017-12-18',
#     'sha1': '73bf45738195d9e48702676cad982a1b1e4927df',
#     'title': 'no title'},
#    'html': '<?xml version=\'1.0\' encoding=\'UTF-8\' standalone=\'yes\'?><html>\n<head>\n    <meta content="text/html; charset=UTF-8" http-equiv="Content-Type"/>\n\n<style type="text/css">/**//**/</style>\n<meta content="Janhavi Dabir" name="author"/>\n<meta content="2017-12-18" name="publicationdate"/>\n\n<title>no title</title></head>\n<body class="b1">\n\n<div id="content">\n<p dir="ltr">If a dose of Xarelto® is not taken at the scheduled time, administer the dose as soon as possible on the same day.</p>\n<p dir="ltr">For patients receiving 15 mg twice daily: The patient should take Xarelto® immediately to ensure intake of 30 mg Xarelto® per day. In this particular instance, two 15 mg tablets may be taken at once. The patient should continue with the regular 15 mg twice daily intake as recommended on the following day.</p>\n<p dir="ltr">For patients receiving 20 mg, 15 mg or 10 mg once daily: The patient should take the missed Xarelto® dose immediately.</p>\n</div>\n\n</body></html>',
#    'id': 'c95997bd22352b12be390d1da577f9f4',
#    'result_metadata': {'confidence': 0.9703002305189965, 'score': 2.811204},
#    'text': 'no title\n\nIf a dose of Xarelto® is not taken at the scheduled time, administer the dose as soon as possible on the same day.\n\nFor patients receiving 15 mg twice daily: The patient should take Xarelto® immediately to ensure intake of 30 mg Xarelto® per day. In this particular instance, two 15 mg tablets may be taken at once. The patient should continue with the regular 15 mg twice daily intake as recommended on the following day.\n\nFor patients receiving 20 mg, 15 mg or 10 mg once daily: The patient should take the missed Xarelto® dose immediately.'},
#   {'enriched_text': {'categories': [{'label': '/health and fitness/therapy',
#       'score': 0.499526},
#      {'label': '/health and fitness/disorders', 'score': 0.266549},
#      {'label': '/science/medicine/surgery', 'score': 0.24009}],
#     'concepts': [{'dbpedia_resource': 'http://dbpedia.org/resource/Therapeutic_effect',
#       'relevance': 0.920839,
#       'text': 'Therapeutic effect'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Medicine',
#       'relevance': 0.826499,
#       'text': 'Medicine'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Blood_transfusion',
#       'relevance': 0.795776,
#       'text': 'Blood transfusion'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Pharmacology',
#       'relevance': 0.782739,
#       'text': 'Pharmacology'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Anticoagulant',
#       'relevance': 0.644805,
#       'text': 'Anticoagulant'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Surgery',
#       'relevance': 0.627417,
#       'text': 'Surgery'}],
#     'entities': [{'count': 2,
#       'relevance': 0.01,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '24 hours',
#       'type': 'Quantity'}],
#     'sentiment': {'document': {'label': 'negative', 'score': -0.733839}}},
#    'extracted_metadata': {'author': 'Janhavi Dabir',
#     'file_type': 'word',
#     'filename': 'Discontinuation for surgery.docx',
#     'publicationdate': '2017-12-18',
#     'sha1': '69559190b539b6cd1e2ecdce0390f606f6ffd3b7',
#     'title': 'no title'},
#    'html': '<?xml version=\'1.0\' encoding=\'UTF-8\' standalone=\'yes\'?><html>\n<head>\n    <meta content="text/html; charset=UTF-8" http-equiv="Content-Type"/>\n\n<style type="text/css">/**//**/</style>\n<meta content="Janhavi Dabir" name="author"/>\n<meta content="2017-12-18" name="publicationdate"/>\n\n<title>no title</title></head>\n<body class="b1">\n\n<div id="content">\n<p dir="ltr">If anticoagulation must be discontinued to reduce the risk of bleeding with surgical or other procedures, Xarelto® should be stopped at least 24 hours before the procedure to reduce the risk of bleeding. In deciding whether a procedure should be delayed until 24 hours after the last dose of Xarelto®, the increased risk of bleeding should be weighed against the urgency of intervention. Xarelto® should be restarted after the surgical or other procedures as soon as adequate hemostasis has been established, noting that the time to onset of therapeutic effect is short. If oral medication cannot be taken during or after surgical intervention, consider administering a parenteral anticoagulant. </p>\n<p dir="ltr">\xa0</p>\n</div>\n\n</body></html>',
#    'id': '4523137ed853c344d62b8ab4de81ec1e',
#    'result_metadata': {'confidence': 0.0811019375703541, 'score': 0.36557308},
#    'text': 'no title\n\nIf anticoagulation must be discontinued to reduce the risk of bleeding with surgical or other procedures, Xarelto® should be stopped at least 24 hours before the procedure to reduce the risk of bleeding. In deciding whether a procedure should be delayed until 24 hours after the last dose of Xarelto®, the increased risk of bleeding should be weighed against the urgency of intervention. Xarelto® should be restarted after the surgical or other procedures as soon as adequate hemostasis has been established, noting that the time to onset of therapeutic effect is short. If oral medication cannot be taken during or after surgical intervention, consider administering a parenteral anticoagulant.\n\n\xa0'},
#   {'enriched_text': {'categories': [{'label': '/health and fitness/therapy',
#       'score': 0.588006},
#      {'label': '/health and fitness/disorders', 'score': 0.445988},
#      {'label': '/health and fitness/disease', 'score': 0.351611}],
#     'concepts': [{'dbpedia_resource': 'http://dbpedia.org/resource/Pharmacology',
#       'relevance': 0.962029,
#       'text': 'Pharmacology'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Hemostasis',
#       'relevance': 0.5271,
#       'text': 'Hemostasis'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Coagulation',
#       'relevance': 0.5103,
#       'text': 'Coagulation'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Platelet',
#       'relevance': 0.491288,
#       'text': 'Platelet'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Biological_half-life',
#       'relevance': 0.4873,
#       'text': 'Biological half-life'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Clopidogrel',
#       'relevance': 0.474336,
#       'text': 'Clopidogrel'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Illness',
#       'relevance': 0.463418,
#       'text': 'Illness'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Adenosine_diphosphate',
#       'relevance': 0.435849,
#       'text': 'Adenosine diphosphate'}],
#     'entities': [{'count': 2,
#       'relevance': 0.747354,
#       'sentiment': {'label': 'negative', 'score': -0.314867},
#       'text': 'clopidogrel',
#       'type': 'Drug'},
#      {'count': 2,
#       'relevance': 0.731775,
#       'sentiment': {'label': 'negative', 'score': -0.314867},
#       'text': 'DRUGX',
#       'type': 'Company'},
#      {'count': 1,
#       'relevance': 0.731775,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '45 minutes',
#       'type': 'Quantity'},
#      {'count': 1,
#       'relevance': 0.731775,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '300 mg',
#       'type': 'Quantity'},
#      {'count': 1,
#       'relevance': 0.731775,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '15 mg',
#       'type': 'Quantity'},
#      {'count': 1,
#       'relevance': 0.731775,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '75 mg',
#       'type': 'Quantity'},
#      {'count': 1,
#       'relevance': 0.731775,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '30%',
#       'type': 'Quantity'},
#      {'count': 1,
#       'relevance': 0.731775,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '45%',
#       'type': 'Quantity'}],
#     'sentiment': {'document': {'label': 'negative', 'score': -0.0468971}}},
#    'extracted_metadata': {'author': 'Sandeep Gantotti',
#     'file_type': 'word',
#     'filename': 'DrugX_DI_clopidogrel.docx',
#     'publicationdate': '2017-12-22',
#     'sha1': 'c600f43e7a34da25b83d1eb96714d3fd5443c965',
#     'title': 'no title'},
#    'html': '<?xml version=\'1.0\' encoding=\'UTF-8\' standalone=\'yes\'?><html>\n<head>\n    <meta content="text/html; charset=UTF-8" http-equiv="Content-Type"/>\n\n<style type="text/css">/**//**/</style>\n<meta content="Sandeep Gantotti" name="author"/>\n<meta content="2017-12-22" name="publicationdate"/>\n\n<title>no title</title></head>\n<body class="b1">\n\n<div id="content">\n<p dir="ltr">Concomitant use of other drugs that impair hemostasis increases the risk of bleeding, including P2Y12 platelet inhibitors.</p>\n<p dir="ltr">Coadministration of clopidogrel and DRUGX did not affect the pharmacokinetics of either drug, however, clopidogrel (300 mg loading dose followed by 75 mg daily maintenance dose) and DRUGX (15 mg single dose) administration in healthy subjects resulted in an increase in bleeding time to 45 minutes and approximately twice the maximum increase seen with either drug alone, in 30% to 45% of patients.</p>\n</div>\n\n</body></html>',
#    'id': 'd6aae77cbbd4ef194872f4b71497e6a2',
#    'result_metadata': {'confidence': 0.07812263967469309, 'score': 0.5325016},
#    'text': 'no title\n\nConcomitant use of other drugs that impair hemostasis increases the risk of bleeding, including P2Y12 platelet inhibitors.\n\nCoadministration of clopidogrel and DRUGX did not affect the pharmacokinetics of either drug, however, clopidogrel (300 mg loading dose followed by 75 mg daily maintenance dose) and DRUGX (15 mg single dose) administration in healthy subjects resulted in an increase in bleeding time to 45 minutes and approximately twice the maximum increase seen with either drug alone, in 30% to 45% of patients.'},
#   {'enriched_text': {'categories': [{'label': '/health and fitness/disease/gerd and acid reflux',
#       'score': 0.51138},
#      {'label': '/science/medicine', 'score': 0.393118},
#      {'label': '/health and fitness/disease', 'score': 0.166493}],
#     'concepts': [],
#     'entities': [{'count': 1,
#       'relevance': 0.941727,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': 'omeprazole',
#       'type': 'Drug'},
#      {'count': 1,
#       'relevance': 0.330925,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': 'rivaroxaban',
#       'type': 'Drug'},
#      {'count': 1,
#       'relevance': 0.330925,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '30 mg',
#       'type': 'Quantity'},
#      {'count': 1,
#       'relevance': 0.330925,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '40 mg',
#       'type': 'Quantity'}],
#     'sentiment': {'document': {'label': 'neutral', 'score': 0}}},
#    'extracted_metadata': {'author': 'Sandeep Gantotti',
#     'file_type': 'word',
#     'filename': 'DrugX_DI_omeprazole.docx',
#     'publicationdate': '2017-12-22',
#     'sha1': 'f98de83e4b424f4e10821d784315deefe1039db4',
#     'title': 'no title'},
#    'html': '<?xml version=\'1.0\' encoding=\'UTF-8\' standalone=\'yes\'?><html>\n<head>\n    <meta content="text/html; charset=UTF-8" http-equiv="Content-Type"/>\n\n<style type="text/css">/**//**/</style>\n<meta content="Sandeep Gantotti" name="author"/>\n<meta content="2017-12-22" name="publicationdate"/>\n\n<title>no title</title></head>\n<body class="b1">\n\n<div id="content">\n<p dir="ltr">Coadministration of DrugX  (30 mg single dose) with omeprazole (40 mg once daily) did not affect the bioavailability and exposure of rivaroxaban.</p>\n<p dir="ltr">\xa0</p>\n</div>\n\n</body></html>',
#    'id': 'd1db29738b911f24133edf49859e17bc',
#    'result_metadata': {'confidence': 0.07729234683497296, 'score': 0.45655766},
#    'text': 'no title\n\nCoadministration of DrugX (30 mg single dose) with omeprazole (40 mg once daily) did not affect the bioavailability and exposure of rivaroxaban.\n\n\xa0'},
#   {'enriched_text': {'categories': [{'label': '/health and fitness/disease/asthma',
#       'score': 0.636056},
#      {'label': '/health and fitness/therapy', 'score': 0.50586},
#      {'label': '/health and fitness/drugs', 'score': 0.253664}],
#     'concepts': [{'dbpedia_resource': 'http://dbpedia.org/resource/H2_antagonist',
#       'relevance': 0.886784,
#       'text': 'H2 antagonist'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Histamine',
#       'relevance': 0.82944,
#       'text': 'Histamine'}],
#     'entities': [{'count': 1,
#       'relevance': 0.956463,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': 'ranitidine',
#       'type': 'Drug'},
#      {'count': 1,
#       'relevance': 0.373516,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': 'rivaroxaban',
#       'type': 'Drug'},
#      {'count': 1,
#       'relevance': 0.373516,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '150 mg',
#       'type': 'Quantity'},
#      {'count': 1,
#       'relevance': 0.373516,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '30 mg',
#       'type': 'Quantity'}],
#     'sentiment': {'document': {'label': 'neutral', 'score': 0}}},
#    'extracted_metadata': {'author': 'Sandeep Gantotti',
#     'file_type': 'word',
#     'filename': 'DrugX_DI_ranitidine.docx',
#     'publicationdate': '2017-12-22',
#     'sha1': 'ee67e4779478f11d4db1588987b239f2e075736e',
#     'title': 'no title'},
#    'html': '<?xml version=\'1.0\' encoding=\'UTF-8\' standalone=\'yes\'?><html>\n<head>\n    <meta content="text/html; charset=UTF-8" http-equiv="Content-Type"/>\n\n<style type="text/css">/**//**/</style>\n<meta content="Sandeep Gantotti" name="author"/>\n<meta content="2017-12-22" name="publicationdate"/>\n\n<title>no title</title></head>\n<body class="b1">\n\n<div id="content">\n<p dir="ltr">Coadministration of DrugX (30 mg single dose) with the H2-receptor antagonist ranitidine (150 mg twice daily) did not affect the bioavailability and exposure of rivaroxaban.</p>\n</div>\n\n</body></html>',
#    'id': '631a5efb71eccd1491013134836b7940',
#    'result_metadata': {'confidence': 0.07729234683497296, 'score': 0.45655766},
#    'text': 'no title\n\nCoadministration of DrugX (30 mg single dose) with the H2-receptor antagonist ranitidine (150 mg twice daily) did not affect the bioavailability and exposure of rivaroxaban.'},
#   {'enriched_text': {'categories': [{'label': '/health and fitness/disease',
#       'score': 0.238709},
#      {'label': '/health and fitness/disease/headaches and migraines',
#       'score': 0.204637},
#      {'label': '/health and fitness/disease/heart disease',
#       'score': 0.171552}],
#     'concepts': [{'dbpedia_resource': 'http://dbpedia.org/resource/Atrial_fibrillation',
#       'relevance': 0.915043,
#       'text': 'Atrial fibrillation'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Risk',
#       'relevance': 0.877852,
#       'text': 'Risk'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Warfarin',
#       'relevance': 0.805703,
#       'text': 'Warfarin'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Atrial_flutter',
#       'relevance': 0.598437,
#       'text': 'Atrial flutter'}],
#     'entities': [{'count': 3,
#       'relevance': 0.881738,
#       'sentiment': {'label': 'negative', 'score': -0.585888},
#       'text': 'aspirin',
#       'type': 'Drug'},
#      {'count': 1,
#       'relevance': 0.190842,
#       'sentiment': {'label': 'negative', 'score': -0.724414},
#       'text': 'DRUGX',
#       'type': 'Company'},
#      {'count': 1,
#       'relevance': 0.158358,
#       'sentiment': {'label': 'negative', 'score': -0.472425},
#       'text': 'rivaroxaban',
#       'type': 'Drug'},
#      {'count': 1,
#       'relevance': 0.158358,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '100mg',
#       'type': 'Quantity'}],
#     'sentiment': {'document': {'label': 'negative', 'score': -0.662734}}},
#    'extracted_metadata': {'author': 'Sandeep Gantotti',
#     'file_type': 'word',
#     'filename': 'DrugX_DI_ASA.docx',
#     'publicationdate': '2017-12-22',
#     'sha1': '0e5553ef53cda01d9e5f8079722a72ee61c69502',
#     'title': 'no title'},
#    'html': '<?xml version=\'1.0\' encoding=\'UTF-8\' standalone=\'yes\'?><html>\n<head>\n    <meta content="text/html; charset=UTF-8" http-equiv="Content-Type"/>\n\n<style type="text/css">/**//**/</style>\n<meta content="Sandeep Gantotti" name="author"/>\n<meta content="2017-12-22" name="publicationdate"/>\n\n<title>no title</title></head>\n<body class="b1">\n\n<div id="content">\n<p dir="ltr">Concurrent use of DRUGX with other aspirin should be avoided due to increased bleeding risk, unless benefits outweigh risks.</p>\n<p dir="ltr">Aspirin did not affect the pharmacokinetics of rivaroxaban, however, in the pivotal atrial fibrillation study, aspirin at doses &lt; 100mg was an independent risk factor for bleeding.</p>\n</div>\n\n</body></html>',
#    'id': '5e2c0d0a4c9f97d7b172d0a4019f81d6',
#    'result_metadata': {'confidence': 0.06589305340472826, 'score': 0.40242854},
#    'text': 'no title\n\nConcurrent use of DRUGX with other aspirin should be avoided due to increased bleeding risk, unless benefits outweigh risks.\n\nAspirin did not affect the pharmacokinetics of rivaroxaban, however, in the pivotal atrial fibrillation study, aspirin at doses < 100mg was an independent risk factor for bleeding.'},
#   {'enriched_text': {'categories': [{'label': '/health and fitness/therapy',
#       'score': 0.687433},
#      {'label': '/science/medicine/surgery', 'score': 0.215523},
#      {'label': '/health and fitness/disease', 'score': 0.157361}],
#     'concepts': [{'dbpedia_resource': 'http://dbpedia.org/resource/Warfarin',
#       'relevance': 0.971007,
#       'text': 'Warfarin'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Coagulation',
#       'relevance': 0.69675,
#       'text': 'Coagulation'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Vitamin_K',
#       'relevance': 0.659813,
#       'text': 'Vitamin K'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Anticoagulants',
#       'relevance': 0.582902,
#       'text': 'Anticoagulants'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Risk',
#       'relevance': 0.520828,
#       'text': 'Risk'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/MG_Cars',
#       'relevance': 0.506358,
#       'text': 'MG Cars'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Magnesium',
#       'relevance': 0.492313,
#       'text': 'Magnesium'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Anticoagulant',
#       'relevance': 0.474214,
#       'text': 'Anticoagulant'}],
#     'entities': [{'count': 2,
#       'relevance': 0.85037,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': 'Warfarin',
#       'type': 'Drug'},
#      {'count': 1,
#       'relevance': 0.225379,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': 'rivaroxaban',
#       'type': 'Drug'},
#      {'count': 1,
#       'relevance': 0.225379,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '15 mg',
#       'type': 'Quantity'},
#      {'count': 1,
#       'relevance': 0.225379,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '5mg',
#       'type': 'Quantity'}],
#     'sentiment': {'document': {'label': 'negative', 'score': -0.653345}}},
#    'extracted_metadata': {'author': 'Sandeep Gantotti',
#     'file_type': 'word',
#     'filename': 'DrugX_DI_warfarin.docx',
#     'publicationdate': '2017-12-22',
#     'sha1': '48b7e3060438d2d39140941fad3278ce687f2e38',
#     'title': 'no title'},
#    'html': '<?xml version=\'1.0\' encoding=\'UTF-8\' standalone=\'yes\'?><html>\n<head>\n    <meta content="text/html; charset=UTF-8" http-equiv="Content-Type"/>\n\n<style type="text/css">/**//**/</style>\n<meta content="Sandeep Gantotti" name="author"/>\n<meta content="2017-12-22" name="publicationdate"/>\n\n<title>no title</title></head>\n<body class="b1">\n\n<div id="content">\n<p dir="ltr">Concurrent use of DrugX with other anticoagulants should be avoided due to increased bleeding risk, unless benefits outweigh risks.</p>\n<p dir="ltr">Warfarin did not alter the pharmacokinetics of rivaroxaban, however single doses of warfarin 15 mg and DrugX  (5mg) resulted an additive effect on factor Xa inhibition and PT.</p>\n</div>\n\n</body></html>',
#    'id': 'e86a7d854bfeb6180e6c1cc584bcfa9f',
#    'result_metadata': {'confidence': 0.06589305340472826, 'score': 0.40242854},
#    'text': 'no title\n\nConcurrent use of DrugX with other anticoagulants should be avoided due to increased bleeding risk, unless benefits outweigh risks.\n\nWarfarin did not alter the pharmacokinetics of rivaroxaban, however single doses of warfarin 15 mg and DrugX (5mg) resulted an additive effect on factor Xa inhibition and PT.'},
#   {'enriched_text': {'categories': [{'label': '/food and drink/food/fruits and vegetables',
#       'score': 0.581778},
#      {'label': '/science/medicine', 'score': 0.543488},
#      {'label': '/health and fitness/disease/asthma', 'score': 0.341784}],
#     'concepts': [{'dbpedia_resource': 'http://dbpedia.org/resource/Patient',
#       'relevance': 0.938227,
#       'text': 'Patient'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Patience_(disambiguation)',
#       'relevance': 0.811842,
#       'text': 'Patience'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/English-language_films',
#       'relevance': 0.645975,
#       'text': 'English-language films'},
#      {'dbpedia_resource': 'http://dbpedia.org/resource/Following',
#       'relevance': 0.644805,
#       'text': 'Following'}],
#     'entities': [{'count': 2,
#       'relevance': 0.01,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '15 mg',
#       'type': 'Quantity'},
#      {'count': 1,
#       'relevance': 0.01,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': 'two 15 mg',
#       'type': 'Quantity'},
#      {'count': 1,
#       'relevance': 0.01,
#       'sentiment': {'label': 'neutral', 'score': 0},
#       'text': '30 mg',
#       'type': 'Quantity'}],
#     'sentiment': {'document': {'label': 'positive', 'score': 0.161415}}},
#    'extracted_metadata': {'author': 'Janhavi Dabir',
#     'file_type': 'word',
#     'filename': 'Missed dose 15 mg twice daily.docx',
#     'publicationdate': '2017-12-18',
#     'sha1': '91d029268f785c07d9c7ab5d97f730b61cf1bd48',
#     'title': 'no title'},
#    'html': '<?xml version=\'1.0\' encoding=\'UTF-8\' standalone=\'yes\'?><html>\n<head>\n    <meta content="text/html; charset=UTF-8" http-equiv="Content-Type"/>\n\n<style type="text/css">/**//**/</style>\n<meta content="Janhavi Dabir" name="author"/>\n<meta content="2017-12-18" name="publicationdate"/>\n\n<title>no title</title></head>\n<body class="b1">\n\n<div id="content">\n<p dir="ltr">If a dose of DrugX® is not taken at the scheduled time, administer the dose as soon as possible on the same day. For patients receiving 15 mg twice daily, the patient should take DrugX® immediately to ensure intake of 30 mg DrugX® per day. In this particular instance, two 15 mg tablets may be taken at once. The patient should continue with the regular 15 mg twice daily intake as recommended on the following day.</p>\n</div>\n\n</body></html>',
#    'id': '8c8c438d3e13e604af0a26c0111f5bb2',
#    'result_metadata': {'confidence': 0, 'score': 2.0296068},
#    'text': 'no title\n\nIf a dose of DrugX® is not taken at the scheduled time, administer the dose as soon as possible on the same day. For patients receiving 15 mg twice daily, the patient should take DrugX® immediately to ensure intake of 30 mg DrugX® per day. In this particular instance, two 15 mg tablets may be taken at once. The patient should continue with the regular 15 mg twice daily intake as recommended on the following day.'}],
#  'session_token': '1_GT6qfPGTdU5qZQv3_EnUorFtrn'}

# %% [markdown]
# # Delete All Training Data

# %%
discovery.delete_all_training_data(environment_id, collection_id)

# %% [markdown]
# # Add training data + examples for individual NLQ

# %%
data = {
    "natural_language_query": "what are dos and donts during earthquake", 
        
    "filter": "test2", 
    "examples": [{"document_id": "493fed166c4344bbc5512ac068975514e3cda6b9efb908b2910b204dec4b0d0", "relevance": 2}, 
                 {"document_id": "18ed484753a7f9845b364bdf74f2eb79", "relevance": 1}]
}

headers = {
        "content-type": "application/json",
        "Accept" : "text/plain"
        }

discovery_path = "https://gateway.watsonplatform.net/discovery/api/v1/environments/" + environment_id + "/collections/" + collection_id + "/training_data"
discovery_training_path = discovery_path + "?version=2018-03-05"

username = os.getenv('DISCOVERY_USERNAME')
password = os.getenv('DISCOVERY_PASSWORD')

auth = (username, password)

print(discovery_path, '\n', discovery_training_path)
print(data)
#data = json.dumps(data)
#print(data)

response = requests.request(method="POST",url=discovery_training_path,json=data,headers=headers,auth=auth)
#response = requests.post(url=discovery_path,params=params,json=data,headers=headers)
print(response.json())

#add_training_data(discovery, environment_id, collection_id, natural_language_query='what are dos and donts during earthquake', filter=None, 
                  #examples=examples, **kwargs)
print(response.status_code , response.reason, '\n', response.request, response.url,response.text)
# Out:
# https://gateway.watsonplatform.net/discovery/api/v1/environments/162e8398-ceff-42ab-8710-655087535953/collections/6cd34257-ac8c-43d5-b62f-61e0e9732eca/training_data
#  https://gateway.watsonplatform.net/discovery/api/v1/environments/162e8398-ceff-42ab-8710-655087535953/collections/6cd34257-ac8c-43d5-b62f-61e0e9732eca/training_data?version=2018-03-05
# {'natural_language_query': 'what are dos and donts during earthquake', 'filter': 'test2', 'examples': [{'document_id': '493fed166c4344bbc5512ac068975514e3cda6b9efb908b2910b204dec4b0d0', 'relevance': 2}, {'document_id': '18ed484753a7f9845b364bdf74f2eb79', 'relevance': 1}]}
# {'natural_language_query': 'what are dos and donts during earthquake', 'filter': 'test2', 'examples': [{'document_id': '493fed166c4344bbc5512ac068975514e3cda6b9efb908b2910b204dec4b0d0', 'cross_reference': '', 'relevance': 2, 'created': '2018-08-08T05:17:16.284Z', 'updated': '2018-08-08T05:17:16.306Z'}, {'document_id': '18ed484753a7f9845b364bdf74f2eb79', 'cross_reference': '', 'relevance': 1, 'created': '2018-08-08T05:17:16.284Z', 'updated': '2018-08-08T05:17:16.311Z'}], 'query_id': '8bd44b5c90fafd50a7cff98618c2837211c6c79f', 'created': '2018-08-08T05:17:16.273Z', 'updated': '2018-08-08T05:17:16.273Z'}
# 201 Created
#  <PreparedRequest [POST]> https://gateway.watsonplatform.net/discovery/api/v1/environments/162e8398-ceff-42ab-8710-655087535953/collections/6cd34257-ac8c-43d5-b62f-61e0e9732eca/training_data?version=2018-03-05 {"natural_language_query":"what are dos and donts during earthquake","filter":"test2","examples":[{"document_id":"493fed166c4344bbc5512ac068975514e3cda6b9efb908b2910b204dec4b0d0","cross_reference":"","relevance":2,"created":"2018-08-08T05:17:16.284Z","updated":"2018-08-08T05:17:16.306Z"},{"document_id":"18ed484753a7f9845b364bdf74f2eb79","cross_reference":"","relevance":1,"created":"2018-08-08T05:17:16.284Z","updated":"2018-08-08T05:17:16.311Z"}],"query_id":"8bd44b5c90fafd50a7cff98618c2837211c6c79f","created":"2018-08-08T05:17:16.273Z","updated":"2018-08-08T05:17:16.273Z"}

# %%
json_output = json.loads(response.text)
query_id=json_output['query_id']
print(query_id)
# Out:
# 8bd44b5c90fafd50a7cff98618c2837211c6c79f

# %% [markdown]
# # Add example to existing query

# %%
query_id = 8bd44b5c90fafd50a7cff98618c2837211c6c79f
data = {
   "document_id": "493fed166c4344bbc5512ac068975514e3cda6b9efb908b2910b204dec4b0d06",
   "relevance": 1
 }
json_output = json.loads(response.text)
add_example_path = discovery_path + "/" + query_id + "/examples?version=2018-03-05"
print(add_example_path)
response = requests.request(method="POST",url=add_example_path,json=data,headers=headers,auth=auth)
print(response.status_code , response.reason, '\n', response.request, response.url,response.text)
# Out:
# https://gateway.watsonplatform.net/discovery/api/v1/environments/162e8398-ceff-42ab-8710-655087535953/collections/6cd34257-ac8c-43d5-b62f-61e0e9732eca/training_data/8bd44b5c90fafd50a7cff98618c2837211c6c79f/examples?version=2018-03-05
# 201 Created
#  <PreparedRequest [POST]> https://gateway.watsonplatform.net/discovery/api/v1/environments/162e8398-ceff-42ab-8710-655087535953/collections/6cd34257-ac8c-43d5-b62f-61e0e9732eca/training_data/8bd44b5c90fafd50a7cff98618c2837211c6c79f/examples?version=2018-03-05 {"document_id":"493fed166c4344bbc5512ac068975514e3cda6b9efb908b2910b204dec4b0d06","cross_reference":"","relevance":1,"created":"2018-08-08T05:23:54.384Z","updated":"2018-08-08T05:23:54.530Z"}

# %%
# Dictionary of string and int
wordFreqDic = {
    "Hello": 56,
    "at" : 23 ,
    "test" : 43,
    "this" : 78,
    "test2" :{
        "nkey1": "value1"
    }
}

# %%
if "test2" in wordFreqDic:
    print("Yes 'test2' key exists in dict")
else:
    print("No 'test' key does not exists in dict") 
if ("nkey1") in wordFreqDic:
 print("Yes 'nkey1' key exists in dict")
else:
    print("No 'nkey1' key does not exists in dict")
print(wordFreqDic.get('test2'))
if('nkey1' in wordFreqDic.get('test2')):
    print("Yes 'nkey1' key exists in dict")
else:
    print("No 'nkey1' key does not exists in dict")
# Out:
# Yes 'test2' key exists in dict
# No 'nkey1' key does not exists in dict
# {'nkey1': 'value1'}
# Yes 'nkey1' key exists in dict

# %%
import requests

headers = {
        "content-type": "application/json",
        "Accept" : "text/plain"
        }
data = {
    "natural_language_query": "what are dos and donts during earthquake", 
        
    "filter": "test2", 
    "examples": [{"document_id": "493fed166c4344bbc5512ac068975514e3cda6b9efb908b2910b204dec4b0d0", "relevance": 2}, 
                 {"document_id": "18ed484753a7f9845b364bdf74f2eb79", "relevance": 1}]
}

req = requests.Request('POST','https://gateway.watsonplatform.net/discovery/api/v1/environments/162e8398-ceff-42ab-8710-655087535953/collections/6cd34257-ac8c-43d5-b62f-61e0e9732eca/training_data?version=2018-03-05',headers=headers,data=data)
prepared = req.prepare()

def pretty_print_POST(req):
    """
    At this point it is completely built and ready
    to be fired; it is "prepared".

    However pay attention at the formatting used in 
    this function because it is programmed to be pretty 
    printed and may differ from the actual request.
    """
    print('{}\n{}\n{}\n\n{}'.format(
        '-----------START-----------',
        req.method + ' ' + req.url,
        '\n'.join('{}: {}'.format(k, v) for k, v in req.headers.items()),
        req.body,
    ))

pretty_print_POST(prepared)
# Out:
# -----------START-----------
# POST https://gateway.watsonplatform.net/discovery/api/v1/environments/162e8398-ceff-42ab-8710-655087535953/collections/6cd34257-ac8c-43d5-b62f-61e0e9732eca/training_data?version=2018-03-05
# content-type: application/json
# Content-Length: 143
#
# natural_language_query=what+are+dos+and+donts+during+earthquake&examples=document_id&examples=relevance&examples=document_id&examples=relevance
