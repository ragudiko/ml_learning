# %%
# !pip install --upgrade "ibm-watson>=4.3.0"
# Out:
# Looking in indexes: https://ragudiko%40in.ibm.com:****@na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-nlp-pypi-virtual/simple
# Collecting ibm-watson>=4.3.0
#   Downloading https://na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-nlp-pypi-virtual/packages/packages/68/b8/b0cbd12e1813a8cc936619e88e1c54a3475dcb38aff7595b339ddf75fd39/ibm-watson-4.3.0.tar.gz (360 kB)
#      |████████████████████████████████| 360 kB 194 kB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: requests<3.0,>=2.0 in /opt/anaconda3/lib/python3.7/site-packages (from ibm-watson>=4.3.0) (2.22.0)
# Requirement already satisfied, skipping upgrade: python_dateutil>=2.5.3 in /opt/anaconda3/lib/python3.7/site-packages (from ibm-watson>=4.3.0) (2.8.1)
# Collecting websocket-client==0.48.0
#   Downloading https://na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-nlp-pypi-virtual/packages/packages/8a/a1/72ef9aa26cfe1a75cee09fc1957e4723add9de098c15719416a1ee89386b/websocket_client-0.48.0-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 207 kB/s eta 0:00:01
# Collecting ibm_cloud_sdk_core==1.5.1
#   Downloading https://na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-nlp-pypi-virtual/packages/packages/b7/f6/10d5271c807d73d236e6ae07b68035fed78b28b5ab836704d34097af3986/ibm-cloud-sdk-core-1.5.1.tar.gz (25 kB)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests<3.0,>=2.0->ibm-watson>=4.3.0) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests<3.0,>=2.0->ibm-watson>=4.3.0) (2.8)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests<3.0,>=2.0->ibm-watson>=4.3.0) (2019.11.28)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests<3.0,>=2.0->ibm-watson>=4.3.0) (1.25.8)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /opt/anaconda3/lib/python3.7/site-packages (from python_dateutil>=2.5.3->ibm-watson>=4.3.0) (1.14.0)
# Collecting PyJWT>=1.7.1
#   Downloading https://na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-nlp-pypi-virtual/packages/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Building wheels for collected packages: ibm-watson, ibm-cloud-sdk-core
#   Building wheel for ibm-watson (setup.py) ... done
#   Created wheel for ibm-watson: filename=ibm_watson-4.3.0-py3-none-any.whl size=354168 sha256=f81be21465b5ed4dedc397d06cb6fb3404022a70e1438a5905bc7d7725850740
#   Stored in directory: /Users/rajeshgudikoti/Library/Caches/pip/wheels/3b/95/a7/d62f3bd72ffd3f1ab0d281ac714a6428bfcae8f1c237882221
#   Building wheel for ibm-cloud-sdk-core (setup.py) ... done
#   Created wheel for ibm-cloud-sdk-core: filename=ibm_cloud_sdk_core-1.5.1-py3-none-any.whl size=44489 sha256=dd95bdff9c48c13fd579b85d9edb0acca27ff4fd0501440d38f774f84e90825f
#   Stored in directory: /Users/rajeshgudikoti/Library/Caches/pip/wheels/dc/58/eb/9e021c6865eeec90aa3ce0486dfcd84b7a92e20c74cac88afa
# Successfully built ibm-watson ibm-cloud-sdk-core
# Installing collected packages: websocket-client, PyJWT, ibm-cloud-sdk-core, ibm-watson
# Successfully installed PyJWT-1.7.1 ibm-cloud-sdk-core-1.5.1 ibm-watson-4.3.0 websocket-client-0.48.0

# %%
# !pip install python-dotenv
# Out:
# Looking in indexes: https://ragudiko%40in.ibm.com:****@na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-nlp-pypi-virtual/simple
# Collecting python-dotenv
#   Downloading https://na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-nlp-pypi-virtual/packages/packages/cb/2a/07f87440444fdf2c5870a710b6770d766a1c7df9c827b0c90e807f1fb4c5/python_dotenv-0.13.0-py2.py3-none-any.whl (17 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-0.13.0

# %%
import os
import sys
import errno
#from watson_developer_cloud import DiscoveryV1
from ibm_watson import DiscoveryV1
from dotenv import load_dotenv, find_dotenv
import json
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
try:
    load_dotenv(find_dotenv())
except IOError:
    print('warning: no .env file loaded')

# %% [markdown]
# # Create Discovery instance

# %%
# discovery = DiscoveryV1(
#               #url=os.getenv('DISCOVERY_URL'),
#               username=os.getenv('DISCOVERY_USERNAME'),
#               password=os.getenv('DISCOVERY_PASSWORD'),
#               version="2018-03-05"
#             )
environment_id = os.getenv('DISCOVERY_ENVIRONMENT_ID')
configuration_id = os.getenv('DISCOVERY_CONFIGURATION_ID')
# **************
 # ***************** collection_id =  os.getenv('DISCOVERY_COLLECTION_ID')
# **************
collection_id = "f5b5d638-29f4-4b87-b78c-ed8712bd5226"
service_url = os.getenv('DISCOVERY_URL')
# collection_id = '6cd34257-ac8c-43d5-b62f-61e0e9732eca'
print(' environment_id :',environment_id,'\n configuration_id : ',configuration_id,'\n collection_id : ',collection_id)
# Out:
#  environment_id : e60289c3-c606-4ab3-8cf0-c6c05b5e8381
#  configuration_id :  9eaaf99d-42cb-468b-bc60-a7f41168ecf6
#  collection_id :  dc9c826e-5b6d-46eb-b376-f2b0944d2ba2

# %%
print(os.getenv('DISCOVERY_APIKEY'))
print(os.getenv('DISCOVERY_URL'))
# Out:
# tjiICgQmS5DNS2PvIXaG-AKmE_JM4K_0t2Y_DxiRyi7c
# https://gateway-syd.watsonplatform.net/discovery/api

# %%
#from ibm_cloud_sdk_core.authenticators import BasicAuthenticator

#authenticator = BasicAuthenticator(os.getenv('DISCOVERY_USERNAME'),os.getenv('DISCOVERY_PASSWORD'))

authenticator = IAMAuthenticator(os.getenv('DISCOVERY_APIKEY'))

discovery = DiscoveryV1(
    version='2018-03-05',
    authenticator=authenticator
)

discovery.set_service_url(service_url)

# %% [markdown]
# # List all fields

# %%
fields = discovery.list_fields(environment_id, [collection_id])
#print(json.dumps(fields, indent=2))
print(fields)
# Out:
# {
#     "result": {
#         "fields": [
#             {
#                 "field": "tables.body_cells.id",
#                 "type": "string"
#             },
#             {
#                 "field": "extracted_metadata.title",
#                 "type": "string"
#             },
#             {
#                 "field": "enriched_text.entities.sentiment.score",
#                 "type": "double"
#             },
#             {
#                 "field": "subtitle",
#                 "type": "string"
#             },
#             {
#                 "field": "enriched_text.sentiment.document.label",
#                 "type": "string"
#             },
#             {
#                 "field": "enriched_text.concepts.dbpedia_resource",
#                 "type": "string"
#             },
#             {
#                 "field": "extracted_metadata.file_type",
#                 "type": "string"
#             },
#             {
#                 "field": "segment_metadata.total_segments",
#                 "type": "double"
#             },
#             {
#                 "field": "enriched_text.concepts.text",
#                 "type": "string"
#             },
#             {
#                 "field": "enriched_text.keywords.relevance",
#                 "type": "double"
#             },
#             {
#                 "field": "enriched_text.concepts.relevance",
#                 "type": "double"
#             },
#             {
#                 "field": "enriched_text.categories.score",
#                 "type": "double"
#             },
#             {
#                 "field": "enriched_text.keywords",
#                 "type": "nested"
#             },
#             {
#                 "field": "tables.body_cells",
#                 "type": "nested"
#             },
#             {
#                 "field": "tables.body_cells.row_min",
#                 "type": "double"
#             },
#             {
#                 "field": "segment_metadata.parent_id",
#                 "type": "string"
#             },
#             {
#                 "field": "enriched_text.entities.sentiment.label",
#                 "type": "string"
#             },
#             {
#                 "field": "enriched_text.entities.relevance",
#                 "type": "double"
#             },
#             {
#                 "field": "text",
#                 "type": "string"
#             },
#             {
#                 "field": "enriched_text.entities.count",
#                 "type": "double"
#             },
#             {
#                 "field": "enriched_text.entities.sentiment",
#                 "type": "nested"
#             },
#             {
#                 "field": "enriched_text.sentiment.document",
#                 "type": "nested"
#             },
#             {
#                 "field": "enriched_text.keywords.text",
#                 "type": "string"
#             },
#             {
#                 "field": "enriched_text.entities.text",
#                 "type": "string"
#             },
#             {
#                 "field": "enriched_text.entities",
#                 "type": "nested"
#             },
#             {
#                 "field": "tables.body_cells.cell_text",
#                 "type": "string"
#             },
#             {
#                 "field": "enriched_text.entities.disambiguation.name",
#                 "type": "string"
#             },
#             {
#                 "field": "enriched_text.categories.label",
#                 "type": "string"
#             },
#             {
#                 "field": "enriched_text.keywords.count",
#                 "type": "double"
#             },
#             {
#                 "field": "id",
#                 "type": "string"
#             },
#             {
#                 "field": "enriched_text.concepts",
#                 "type": "nested"
#             },
#             {
#                 "field": "enriched_text.entities.disambiguation",
#                 "type": "nested"
#             },
#             {
#                 "field": "enriched_text.entities.type",
#                 "type": "string"
#             },
#             {
#                 "field": "extracted_metadata.sha1",
#                 "type": "string"
#             },
#             {
#                 "field": "tables.body_cells.row_max",
#                 "type": "double"
#             },
#             {
#                 "field": "enriched_text",
#                 "type": "nested"
#             },
#             {
#                 "field": "enriched_text.categories",
#                 "type": "nested"
#             },
#             {
#                 "field": "extracted_metadata",
#                 "type": "nested"
#             },
#             {
#                 "field": "enriched_text.entities.disambiguation.subtype",
#                 "type": "string"
#             },
#             {
#                 "field": "title",
#                 "type": "string"
#             },
#             {
#                 "field": "enriched_text.sentiment",
#                 "type": "nested"
#             },
#             {
#                 "field": "segment_metadata.id",
#                 "type": "string"
#             },
#             {
#                 "field": "tables.table_text",
#                 "type": "string"
#             },
#             {
#                 "field": "segment_metadata",
#                 "type": "nested"
#             },
#             {
#                 "field": "tables.body_cells.column_max",
#                 "type": "double"
#             },
#             {
#                 "field": "enriched_text.entities.disambiguation.dbpedia_resource",
#                 "type": "string"
#             },
#             {
#                 "field": "enriched_text.sentiment.document.score",
#                 "type": "double"
#             },
#             {
#                 "field": "tables",
#                 "type": "nested"
#             },
#             {
#                 "field": "extracted_metadata.filename",
#                 "type": "string"
#             },
#             {
#                 "field": "tables.body_cells.column_min",
#                 "type": "double"
#             }
#         ]
#     },
#     "headers": {
#         "_store": {
#             "content-type": [
#                 "Content-Type",
#                 "application/json;charset=utf-8"
#             ],
#             "content-length": [
#                 "Content-Length",
#                 "449"
#             ],
#             "access-control-allow-origin": [
#                 "Access-Control-Allow-Origin",
#                 "*"
#             ],
#             "access-control-allow-methods": [
#                 "Access-Control-Allow-Methods",
#                 "GET, PUT, POST, DELETE, OPTIONS"
#             ],
#             "cache-control": [
#                 "Cache-Control",
#                 "no-cache, no-store, no-transform, max-age=0"
#             ],
#             "pragma": [
#                 "Pragma",
#                 "no-cache"
#             ],
#             "expires": [
#                 "Expires",
#                 "0"
#             ],
#             "x-content-type-options": [
#                 "x-content-type-options",
#                 "nosniff"
#             ],
#             "x-xss-protection": [
#                 "x-xss-protection",
#                 "1"
#             ],
#             "content-security-policy": [
#                 "content-security-policy",
#                 "default-src 'none'"
#             ],
#             "access-control-allow-headers": [
#                 "Access-Control-Allow-Headers",
#                 "Origin, Content-Type, Content-Length, Accept, X-Watson-Authorization-Token, X-WDC-PL-OPT-OUT, X-Watson-UserInfo, X-Watson-Learning-Opt-Out, X-Watson-Metadata"
#             ],
#             "content-encoding": [
#                 "Content-Encoding",
#                 "gzip"
#             ],
#             "strict-transport-security": [
#                 "strict-transport-security",
#                 "max-age=31536000; includeSubDomains;"
#             ],
#             "x-global-transaction-id": [
#                 "x-global-transaction-id",
#                 "a2d492147794f5bdcf72aea9f88c7c30"
#             ],
#             "x-dp-watson-tran-id": [
#                 "x-dp-watson-tran-id",
#                 "a2d492147794f5bdcf72aea9f88c7c30"
#             ],
#             "x-edgeconnect-midmile-rtt": [
#                 "X-EdgeConnect-MidMile-RTT",
#                 "295"
#             ],
#             "x-edgeconnect-origin-mex-latency": [
#                 "X-EdgeConnect-Origin-MEX-Latency",
#                 "378"
#             ],
#             "date": [
#                 "Date",
#                 "Tue, 14 Apr 2020 05:35:34 GMT"
#             ],
#             "connection": [
#                 "Connection",
#                 "keep-alive"
#             ],
#             "vary": [
#                 "Vary",
#                 "Accept-Encoding"
#             ]
#         }
#     },
#     "status_code": 200
# }

# %% [markdown]
# # List Configurations in environment

# %%
configs = discovery.list_configurations(environment_id)
print(configs)
# Out:
# {
#     "result": {
#         "configurations": [
#             {
#                 "configuration_id": "3e8581bb-9f88-43f1-8f91-6993f7cae28a",
#                 "name": "Default Configuration",
#                 "description": "The configuration used by default when creating a new collection without specifying a configuration_id.",
#                 "created": "2019-03-20T06:23:43.964Z",
#                 "updated": "2019-03-20T06:23:43.964Z"
#             },
#             {
#                 "configuration_id": "d02571e7-4a9c-4402-903d-d37026e0b549",
#                 "name": "Default Contract Configuration",
#                 "description": "Extract party, nature, and category from elements in PDFs.",
#                 "created": "2019-03-20T06:23:49.941Z",
#                 "updated": "2019-03-20T06:23:49.941Z"
#             },
#             {
#                 "configuration_id": "9eaaf99d-42cb-468b-bc60-a7f41168ecf6",
#                 "name": "SDU-Learn Configuration xng25ekkp4",
#                 "description": "",
#                 "created": "2019-06-27T17:40:41.251Z",
#                 "updated": "2019-08-29T11:29:14.307Z"
#             },
#             {
#                 "configuration_id": "fc6d7fc4-36a2-403f-89bb-4e4cb8cab627",
#                 "name": "htc-demo Configuration kp1p9rzwqr",
#                 "description": "",
#                 "created": "2019-03-20T06:23:56.618Z",
#                 "updated": "2019-03-22T12:39:23.609Z"
#             },
#             {
#                 "configuration_id": "174c711a-afb8-4d86-97d8-8b9d891b5467",
#                 "name": "multiple_data_source",
#                 "description": "Configuration for testing-  single collection - connected to multiple data source",
#                 "created": "2020-04-16T11:28:16.461Z",
#                 "updated": "2020-04-16T11:28:16.461Z"
#             },
#             {
#                 "configuration_id": "be481dc2-8f97-4420-8371-0acf372a2dd7",
#                 "name": "multiple_data_source3",
#                 "description": "Configuration for testing-  single collection - connected to multiple data source",
#                 "created": "2020-04-22T14:32:15.541Z",
#                 "updated": "2020-04-22T14:32:15.541Z"
#             },
#             {
#                 "configuration_id": "c3a27f86-f7ee-4a1c-9cbd-7f00d789ced3",
#                 "name": "multiple_data_source_2",
#                 "description": "Configuration for testing-  single collection - connected to multiple data source",
#                 "created": "2020-04-22T14:20:25.078Z",
#                 "updated": "2020-04-22T14:20:25.078Z"
#             }
#         ]
#     },
#     "headers": {
#         "_store": {
#             "content-type": [
#                 "Content-Type",
#                 "application/json;charset=utf-8"
#             ],
#             "content-length": [
#                 "Content-Length",
#                 "641"
#             ],
#             "access-control-allow-origin": [
#                 "Access-Control-Allow-Origin",
#                 "*"
#             ],
#             "access-control-allow-methods": [
#                 "Access-Control-Allow-Methods",
#                 "GET, PUT, POST, DELETE, OPTIONS"
#             ],
#             "cache-control": [
#                 "Cache-Control",
#                 "no-cache, no-store, no-transform, max-age=0"
#             ],
#             "pragma": [
#                 "Pragma",
#                 "no-cache"
#             ],
#             "expires": [
#                 "Expires",
#                 "0"
#             ],
#             "x-content-type-options": [
#                 "x-content-type-options",
#                 "nosniff"
#             ],
#             "x-xss-protection": [
#                 "x-xss-protection",
#                 "1"
#             ],
#             "content-security-policy": [
#                 "content-security-policy",
#                 "default-src 'none'"
#             ],
#             "access-control-allow-headers": [
#                 "Access-Control-Allow-Headers",
#                 "Origin, Content-Type, Content-Length, Accept, X-Watson-Authorization-Token, X-WDC-PL-OPT-OUT, X-Watson-UserInfo, X-Watson-Learning-Opt-Out, X-Watson-Metadata"
#             ],
#             "content-encoding": [
#                 "Content-Encoding",
#                 "gzip"
#             ],
#             "strict-transport-security": [
#                 "strict-transport-security",
#                 "max-age=31536000; includeSubDomains;"
#             ],
#             "x-global-transaction-id": [
#                 "x-global-transaction-id",
#                 "92e1d8e3b1a2e1c622dddbe5b6cc41af"
#             ],
#             "x-dp-watson-tran-id": [
#                 "x-dp-watson-tran-id",
#                 "92e1d8e3b1a2e1c622dddbe5b6cc41af"
#             ],
#             "x-edgeconnect-midmile-rtt": [
#                 "X-EdgeConnect-MidMile-RTT",
#                 "301"
#             ],
#             "x-edgeconnect-origin-mex-latency": [
#                 "X-EdgeConnect-Origin-MEX-Latency",
#                 "284"
#             ],
#             "date": [
#                 "Date",
#                 "Fri, 24 Apr 2020 10:57:34 GMT"
#             ],
#             "connection": [
#                 "Connection",
#                 "keep-alive"
#             ],
#             "vary": [
#                 "Vary",
#                 "Accept-Encoding"
#             ]
#         }
#     },
#     "status_code": 200
# }

# %% [markdown]
# # Create collection progrmatically. Use this option in case you are not using collection created by tool. Uncomment the assigning collection to environment variable.

# %%
#new_collection = discovery.create_collection(environment_id=environment_id, configuration_id=configuration_id, 
#                                             name='Nature2', description='Create a Collection to hold natural calmaties information', 
#                                             language='en')
# print(json.dumps(new_collection, indent=2))
# **** Uncomment if you want to use the above created collection further ***
# collection_id = new_collection

# %% [markdown]
# # List Collections in given environment

# %%
collections = discovery.list_collections(environment_id)
print(collections)
# Out:
# {
#     "result": {
#         "collections": [
#             {
#                 "collection_id": "f5b5d638-29f4-4b87-b78c-ed8712bd5226",
#                 "name": "multi_data_source_1",
#                 "configuration_id": "a65cb8e8-05a5-414e-b1d9-7307a27e8ad4",
#                 "language": "en",
#                 "status": "active",
#                 "description": "collection connected to multiple data source- local file system and web crawl",
#                 "created": "2020-04-24T12:09:18.822Z",
#                 "updated": "2020-04-24T12:09:18.822Z"
#             }
#         ]
#     },
#     "headers": {
#         "_store": {
#             "content-type": [
#                 "Content-Type",
#                 "application/json;charset=utf-8"
#             ],
#             "access-control-allow-origin": [
#                 "Access-Control-Allow-Origin",
#                 "*"
#             ],
#             "access-control-allow-methods": [
#                 "Access-Control-Allow-Methods",
#                 "GET, PUT, POST, DELETE, OPTIONS"
#             ],
#             "cache-control": [
#                 "Cache-Control",
#                 "no-cache, no-store, no-transform, max-age=0"
#             ],
#             "pragma": [
#                 "Pragma",
#                 "no-cache"
#             ],
#             "expires": [
#                 "Expires",
#                 "0"
#             ],
#             "x-content-type-options": [
#                 "x-content-type-options",
#                 "nosniff"
#             ],
#             "x-xss-protection": [
#                 "x-xss-protection",
#                 "1"
#             ],
#             "content-security-policy": [
#                 "Content-Security-Policy",
#                 "default-src 'none'"
#             ],
#             "access-control-allow-headers": [
#                 "Access-Control-Allow-Headers",
#                 "Origin, Content-Type, Content-Length, Accept, X-Watson-Authorization-Token, X-WDC-PL-OPT-OUT, X-Watson-UserInfo, X-Watson-Learning-Opt-Out, X-Watson-Metadata"
#             ],
#             "content-encoding": [
#                 "Content-Encoding",
#                 "gzip"
#             ],
#             "strict-transport-security": [
#                 "strict-transport-security",
#                 "max-age=31536000; includeSubDomains;"
#             ],
#             "x-global-transaction-id": [
#                 "x-global-transaction-id",
#                 "fd8232b10cf7005c804a23fb35c6cfa6"
#             ],
#             "x-dp-watson-tran-id": [
#                 "x-dp-watson-tran-id",
#                 "fd8232b10cf7005c804a23fb35c6cfa6"
#             ],
#             "content-length": [
#                 "Content-Length",
#                 "267"
#             ],
#             "x-edgeconnect-midmile-rtt": [
#                 "X-EdgeConnect-MidMile-RTT",
#                 "261"
#             ],
#             "x-edgeconnect-origin-mex-latency": [
#                 "X-EdgeConnect-Origin-MEX-Latency",
#                 "395"
#             ],
#             "date": [
#                 "Date",
#                 "Wed, 09 Sep 2020 11:15:50 GMT"
#             ],
#             "connection": [
#                 "Connection",
#                 "keep-alive"
#             ],
#             "vary": [
#                 "Vary",
#                 "Accept-Encoding"
#             ]
#         }
#     },
#     "status_code": 200
# }

# %% [markdown]
# # Create an environment

# %%
# Only one free environment is allowed per organization ---- so commenting
#response = discovery.create_environment(
#    name="my_environment",
#    description="My environment"
#)

#print(json.dumps(response, indent=2))

# %%
en_de = {"red" : "rot", "green" : "grün", "blue" : "blau", "yellow":"gelb"}
print (en_de)
print (en_de["red"])
de_fr = {"rot" : "rouge", "grün" : "vert", "blau" : "bleu", "gelb":"jaune"}
print ("The French word for red is: " + de_fr[en_de["red"]])
# Out:
# {'red': 'rot', 'green': 'grün', 'blue': 'blau', 'yellow': 'gelb'}
# rot
# The French word for red is: rouge

# %% [markdown]
# # List environments

# %%
environment_info = discovery.list_environments()
print(environment_info)
# Out:
# {
#     "result": {
#         "environments": [
#             {
#                 "environment_id": "system",
#                 "name": "Watson System Environment",
#                 "description": "Shared system data sources",
#                 "read_only": true
#             },
#             {
#                 "environment_id": "162e8398-ceff-42ab-8710-655087535953",
#                 "name": "byod",
#                 "description": "",
#                 "created": "2018-05-04T11:46:30.566Z",
#                 "updated": "2018-05-04T11:46:30.566Z",
#                 "read_only": false
#             }
#         ]
#     },
#     "headers": {
#         "_store": {
#             "x-backside-transport": [
#                 "X-Backside-Transport",
#                 "OK OK"
#             ],
#             "content-type": [
#                 "Content-Type",
#                 "application/json;charset=utf-8"
#             ],
#             "access-control-allow-origin": [
#                 "Access-Control-Allow-Origin",
#                 "*"
#             ],
#             "access-control-allow-methods": [
#                 "Access-Control-Allow-Methods",
#                 "GET, PUT, POST, DELETE, OPTIONS"
#             ],
#             "cache-control": [
#                 "Cache-Control",
#                 "no-cache, no-store, no-transform, max-age=0"
#             ],
#             "pragma": [
#                 "Pragma",
#                 "no-cache"
#             ],
#             "expires": [
#                 "Expires",
#                 "0"
#             ],
#             "x-content-type-options": [
#                 "X-Content-Type-Options",
#                 "nosniff"
#             ],
#             "x-xss-protection": [
#                 "X-XSS-Protection",
#                 "1"
#             ],
#             "content-security-policy": [
#                 "Content-Security-Policy",
#                 "default-src 'none'"
#             ],
#             "access-control-allow-headers": [
#                 "Access-Control-Allow-Headers",
#                 "Origin, Content-Type, Content-Length, Accept, X-Watson-Authorization-Token, X-WDC-PL-OPT-OUT, X-Watson-UserInfo, X-Watson-Learning-Opt-Out, X-Watson-Metadata"
#             ],
#             "x-global-transaction-id": [
#                 "x-global-transaction-id",
#                 "7ecac92c5bf0f2866cd35055"
#             ],
#             "x-dp-watson-tran-id": [
#                 "X-DP-Watson-Tran-ID",
#                 "gateway01-1825787989"
#             ],
#             "x-dp-transit-id": [
#                 "X-DP-Transit-ID",
#                 "gateway01-1825787989"
#             ],
#             "strict-transport-security": [
#                 "Strict-Transport-Security",
#                 "max-age=31536000;"
#             ],
#             "content-encoding": [
#                 "Content-Encoding",
#                 "gzip"
#             ],
#             "content-length": [
#                 "Content-Length",
#                 "228"
#             ],
#             "date": [
#                 "Date",
#                 "Sun, 18 Nov 2018 05:03:02 GMT"
#             ],
#             "connection": [
#                 "Connection",
#                 "keep-alive"
#             ],
#             "vary": [
#                 "Vary",
#                 "Accept-Encoding"
#             ]
#         }
#     },
#     "status_code": 200
# }

# %% [markdown]
# # List environments and list collection for news environment(system)

# %%
environments = discovery.list_environments()
print(json.dumps(environments, indent=2))

#news_environments = [x for x in environments['environments'] if x['name'] == 'Watson Discovery News Environment']
news_environments = [x for x in environments['environments'] if x['name'] == 'Watson System Environment']
print(news_environments, len(news_environments))
news_environment_id = news_environments[0]['environment_id']
print('news environemnt details \n',json.dumps(news_environment_id, indent=2))

collections = discovery.list_collections(news_environment_id)
news_collections = [x for x in collections['collections']]
print('news collection')
print(json.dumps(news_collections, indent=2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-41b2ac145570> in <module>
#       1 environments = discovery.list_environments()
# ----> 2 print(json.dumps(environments, indent=2))
#       3
#       4 #news_environments = [x for x in environments['environments'] if x['name'] == 'Watson Discovery News Environment']
#       5 news_environments = [x for x in environments['environments'] if x['name'] == 'Watson System Environment']
#
# /opt/anaconda3/lib/python3.7/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /opt/anaconda3/lib/python3.7/json/encoder.py in encode(self, o)
#     199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
# --> 201             chunks = list(chunks)
#     202         return ''.join(chunks)
#     203
#
# /opt/anaconda3/lib/python3.7/json/encoder.py in _iterencode(o, _current_indent_level)
#     436                     raise ValueError("Circular reference detected")
#     437                 markers[markerid] = o
# --> 438             o = _default(o)
#     439             yield from _iterencode(o, _current_indent_level)
#     440             if markers is not None:
#
# /opt/anaconda3/lib/python3.7/json/encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type DetailedResponse is not JSON serializable

# %% [markdown]
# # Add a document

# %%
collection_id = '7071bbce-d9d2-464c-83cc-372e18c5f6b6'

# %%
print(os.getcwd())
print(os.path.join('/Users/rajeshgudikoti/Documents/rajesh/project_docs/icici_prudentials/', 'ICICI Pru iProtect Smart.pdf'))
###### rb argument is passed as pdf is binary document ################
with open(os.path.join(os.getcwd(), '/Users/rajeshgudikoti/Documents/rajesh/project_docs/icici_prudentials/', 'ICICI Pru iProtect Smart.pdf'),'rb') as fileinfo:
    add_doc = discovery.add_document(environment_id, collection_id, file=fileinfo, file_content_type='application/pdf',filename='ICICI Pru iProtect Smart.pdf')
# Out:
# /Users/rajeshgudikoti/Documents/rajesh/learning/nlp/discovery
# /Users/rajeshgudikoti/Documents/rajesh/project_docs/icici_prudentials/ICICI Pru iProtect Smart.pdf

# %%
# print(add_doc.result)
print(add_doc.result['status'])
# document_id = add_doc['document_id']
print(add_doc.result['document_id'])
# Out:
# {'document_id': 'd5d9c2c7-c402-4b29-9a35-58ad6b9bec2d', 'status': 'processing'}
# processing
# d5d9c2c7-c402-4b29-9a35-58ad6b9bec2d

# %% [markdown]
# # Add a document reading online

# %%
# !pip install PyPDF2
# If importing module fails even after above command executed sucessfully then navigate to conda prompt and run 
# pip uninstall PyPDF2
# pip install PyPDF2
#https://stackoverflow.com/questions/39241643/no-module-named-pypdf2-error

# %%
import PyPDF2, requests,io

# %%
print('reading online pdffile ')
url = 'https://www.ifc.org/wps/wcm/connect/8b796b004970c0199a7ada336b93d75f/DisERHandbook.pdf?MOD=AJPERES'
response = requests.get(url)
my_raw_data = response.content
#print('raw data ', my_raw_data)
pdf_content = io.BytesIO(my_raw_data)
pdf_reader = PyPDF2.PdfFileReader(pdf_content)

if pdf_reader.isEncrypted:
    pdf_reader.decrypt("")
    print('pdf content decrypted \n', pdf_reader.getPage(0).extractText())

else:
    print('pdf content \n ', pdf_reader.getPage(0).extractText())
num_pages = pdf_reader.getNumPages()
print(num_pages)

# %% [markdown]
# # Add PDF document reading from online

# %%
url = 'https://www.ifc.org/wps/wcm/connect/8b796b004970c0199a7ada336b93d75f/DisERHandbook.pdf?MOD=AJPERES'
response = requests.get(url)
my_raw_data = response.content

with open("/Users/rajeshgudikoti/Documents/github_prj/cfc-fisrt-aid/DisERHandbook.pdf", 'wb') as my_data:
    my_data.write(my_raw_data)

#open_pdf_file = open("/Users/rajeshgudikoti/Documents/github_prj/cfc-fisrt-aid/DisERHandbook.pdf", 'rb')
#read_pdf = PyPDF2.PdfFileReader(open_pdf_file)
#if read_pdf.isEncrypted:
#    read_pdf.decrypt("")
#    print('pdf content decrypted \n', read_pdf.getPage(0).extractText())

#else:
#    print('pdf content \n',read_pdf.getPage(0).extractText())
# num_pages = pdf_reader.getNumPages()
# print(num_pages)

#print(os.path.join('/Users/rajeshgudikoti/Documents/github_prj/cfc-fisrt-aid/', 'DisERHandbook.pdf'))
###### rb argument is passed as pdf is binary document ################
with open(os.path.join(os.getcwd(), '/Users/rajeshgudikoti/Documents/github_prj/cfc-fisrt-aid/DisERHandbook.pdf'),'rb') as fileinfo:
    add_doc = discovery.add_document(environment_id, collection_id, file=fileinfo, file_content_type='application/pdf',filename='DisERHandbook.pdf')
print(json.dumps(add_doc, indent=2))

# %% [markdown]
# # Get document details

# %%
print(add_doc['status'])
document_id = add_doc['document_id']
print(document_id)
# doc_info = discovery.get_document_status(environment_id, collection_id, '3ca7f868-630d-485a-a0ed-6dea26482604')
doc_info = discovery.get_document_status(environment_id, collection_id, document_id)
print(json.dumps(doc_info, indent=2))

# %% [markdown]
# # Update a document

# %%
document_id = 'c148148b6ecf9b218d1b58e3b4d1a572'
with open(os.path.join(os.getcwd(), '/Users/rajeshgudikoti/Documents/github_prj/cfc-fisrt-aid/FS_disaster_toolkit.pdf'),'rb') as fileinfo:
    add_updated_doc = discovery.update_document(environment_id, collection_id, document_id,
                                                file=fileinfo, 
                                                file_content_type='application/pdf',
                                                filename='FS_disaster_toolkit.pdf',
                                                title='FS Disaster Toolkit',
                                                metadata = {'title':"FS Disaster Toolkit"}
                                                )
print(json.dumps(add_updated_doc, indent=2))

# %%
print(add_updated_doc['status'])
document_id = add_updated_doc['document_id']
print(document_id)
doc_info = discovery.get_document_status(environment_id, collection_id, document_id)
print(json.dumps(doc_info, indent=2))

# %%
# Delete a document

# %%
document_id='ac998fbfe448b4d6877f2a17d81f9013_3'
delete_doc = discovery.delete_document(environment_id, collection_id, document_id)
print((delete_doc))
# Out:
# {
#     "result": {
#         "document_id": "ac998fbfe448b4d6877f2a17d81f9013_3",
#         "status": "deleted"
#     },
#     "headers": {
#         "_store": {
#             "content-type": [
#                 "Content-Type",
#                 "application/json;charset=utf-8"
#             ],
#             "content-length": [
#                 "Content-Length",
#                 "97"
#             ],
#             "access-control-allow-origin": [
#                 "Access-Control-Allow-Origin",
#                 "*"
#             ],
#             "access-control-allow-methods": [
#                 "Access-Control-Allow-Methods",
#                 "GET, PUT, POST, DELETE, OPTIONS"
#             ],
#             "cache-control": [
#                 "Cache-Control",
#                 "no-cache, no-store, no-transform, max-age=0"
#             ],
#             "pragma": [
#                 "Pragma",
#                 "no-cache"
#             ],
#             "expires": [
#                 "Expires",
#                 "0"
#             ],
#             "x-content-type-options": [
#                 "x-content-type-options",
#                 "nosniff"
#             ],
#             "x-xss-protection": [
#                 "x-xss-protection",
#                 "1"
#             ],
#             "content-security-policy": [
#                 "content-security-policy",
#                 "default-src 'none'"
#             ],
#             "access-control-allow-headers": [
#                 "Access-Control-Allow-Headers",
#                 "Origin, Content-Type, Content-Length, Accept, X-Watson-Authorization-Token, X-WDC-PL-OPT-OUT, X-Watson-UserInfo, X-Watson-Learning-Opt-Out, X-Watson-Metadata"
#             ],
#             "content-encoding": [
#                 "Content-Encoding",
#                 "gzip"
#             ],
#             "strict-transport-security": [
#                 "strict-transport-security",
#                 "max-age=31536000; includeSubDomains;"
#             ],
#             "x-global-transaction-id": [
#                 "x-global-transaction-id",
#                 "b360038d45eeda89178f03e635aafe35"
#             ],
#             "x-dp-watson-tran-id": [
#                 "x-dp-watson-tran-id",
#                 "b360038d45eeda89178f03e635aafe35"
#             ],
#             "x-edgeconnect-midmile-rtt": [
#                 "X-EdgeConnect-MidMile-RTT",
#                 "235"
#             ],
#             "x-edgeconnect-origin-mex-latency": [
#                 "X-EdgeConnect-Origin-MEX-Latency",
#                 "297"
#             ],
#             "date": [
#                 "Date",
#                 "Tue, 18 Feb 2020 18:42:36 GMT"
#             ],
#             "connection": [
#                 "Connection",
#                 "keep-alive"
#             ],
#             "vary": [
#                 "Vary",
#                 "Accept-Encoding"
#             ]
#         }
#     },
#     "status_code": 200
# }

# %% [markdown]
# # query using discovery query langauge syntax

# %%
qopts = {'query': "entities.text:'Johnny Depp'"}
collection_id = "f5b5d638-29f4-4b87-b78c-ed8712bd5226"
my_query = discovery.query(environment_id, collection_id, query=qopts)
print(json.dumps(my_query, indent=2))
# Out:
# ERROR:root:Exception obtaining parameters
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: Exception obtaining parameters, Code: 500 , X-global-transaction-id: b3a553e89067bc756e6f5ed318179f7c
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# <ipython-input-12-1240110c054c> in <module>
#       1 qopts = {'query': "entities.text:'Johnny Depp'"}
#       2 collection_id = "f5b5d638-29f4-4b87-b78c-ed8712bd5226"
# ----> 3 my_query = discovery.query(environment_id, collection_id, query=qopts)
#       4 print(json.dumps(my_query, indent=2))
#
# /opt/anaconda3/lib/python3.7/site-packages/ibm_watson/discovery_v1.py in query(self, environment_id, collection_id, filter, query, natural_language_query, passages, aggregation, count, return_, offset, sort, highlight, passages_fields, passages_count, passages_characters, deduplicate, deduplicate_field, similar, similar_document_ids, similar_fields, bias, spelling_suggestions, x_watson_logging_opt_out, **kwargs)
#    1741                                        data=data)
#    1742
# -> 1743         response = self.send(request)
#    1744         return response
#    1745
#
# /opt/anaconda3/lib/python3.7/site-packages/ibm_cloud_sdk_core/base_service.py in send(self, request, **kwargs)
#     227                                 'invalid credentials'
#     228             raise ApiException(
# --> 229                 response.status_code, error_message, http_response=response)
#     230         except requests.exceptions.SSLError:
#     231             logging.exception(self.ERROR_MSG_DISABLE_SSL)
#
# ApiException: Error: Exception obtaining parameters, Code: 500 , X-global-transaction-id: b3a553e89067bc756e6f5ed318179f7c

# %%
response= discovery.query(environment_id, collection_id, filter=None, query=None, natural_language_query='four weeks ago', 
                passages=True,
                #aggregation= 'term(classname).top_hits(5)', 
      count=None, return_fields=None, offset=None, sort=None, highlight=None, 
      passages_fields=None, passages_count=None, passages_characters=None, deduplicate=None, deduplicate_field=None)
# print(len(response['passages']))
response.get_result()
# Out:
# {'matching_results': 1,
#  'session_token': '1_HPgOgEV8b37zxrO2_bpQ0nxsHr',
#  'passages': [{'document_id': 'c9b6fd0eabc48035d3dcc161e6ab21b6',
#    'passage_score': 0,
#    'passage_text': '7 Oct 2016 SPOT PRICES - CARGOES OF 500 MT OR MORE Price Range Four Weeks Ago US CTS/lb CFR SE Asia USD/tonne +30 1825.00-1830.00 +30 1775.00-1780.00 82.78-83.01 CFR Taiwan USD/tonne +30 1825.00',
#    'start_offset': 0,
#    'end_offset': 194,
#    'field': 'text'},
#   {'document_id': 'c9b6fd0eabc48035d3dcc161e6ab21b6',
#    'passage_score': 0,
#    'passage_text': '7 Oct 2016 SPOT PRICES - CARGOES OF 500 MT OR MORE Price Range Four Weeks Ago US CTS/lb CFR SE Asia USD/tonne +30 1825.00-1830.00 +30 1775.00-1780.00 82.78-83.01 CFR Taiwan USD/tonne +30 1825.00-1830.00 +30 1775.00-1780.00 82.78-83.01 CFR South Korea USD/tonne +30 1825.00-1830.00 +30 1775.00-1780.00 82.78-83.01 SPOT PRICES - CARGOES OF 20 - 300 MT Price Range Four Weeks Ago US CTS/lb CFR SE Asia',
#    'start_offset': 0,
#    'end_offset': 398,
#    'field': 'text'},
#   {'document_id': 'c9b6fd0eabc48035d3dcc161e6ab21b6',
#    'passage_score': 0,
#    'passage_text': 'Overview - Regional tight supply persists - Firmer market sentiment drives up SE Asia prices - China markets closed for public holiday Price chart: MMA Southeast Asia vs PMMA Southeast Asia Asia spot markets Spot prices of methyl methacrylate (MMA) in southeast Asia were assessed as firmer in the week ended 7 October, bolstered by firmer market discussions amid unabated supply shortfalls.',
#    'start_offset': 638,
#    'end_offset': 1029,
#    'field': 'text'}],
#  'results': [{'id': 'c9b6fd0eabc48035d3dcc161e6ab21b6',
#    'result_metadata': {'score': 1.4340428},
#    'extracted_metadata': {'sha1': '0d80416a05c795f25f2097b48c2803de1563fb41',
#     'filename': 'AP_1_date_added.pdf',
#     'file_type': 'pdf',
#     'title': 'AP_1_date_added'},
#    'text': '7 Oct 2016 SPOT PRICES - CARGOES OF 500 MT OR MORE Price Range Four Weeks Ago US CTS/lb CFR SE Asia USD/tonne +30 1825.00-1830.00 +30 1775.00-1780.00 82.78-83.01 CFR Taiwan USD/tonne +30 1825.00-1830.00 +30 1775.00-1780.00 82.78-83.01 CFR South Korea USD/tonne +30 1825.00-1830.00 +30 1775.00-1780.00 82.78-83.01 SPOT PRICES - CARGOES OF 20 - 300 MT Price Range Four Weeks Ago US CTS/lb CFR SE Asia USD/tonne +30 1830.00-1880.00 +30 1780.00-1850.00 83.01-85.28 Subscriber note: The domestic yuan (CNY) prices in the Methyl Methacrylate (Asia Pacific) weekly report on 7 October 2016 will not be assessed due to a public holiday in China. Overview - Regional tight supply persists - Firmer market sentiment drives up SE Asia prices - China markets closed for public holiday Price chart: MMA Southeast Asia vs PMMA Southeast Asia Asia spot markets Spot prices of methyl methacrylate (MMA) in southeast Asia were assessed as firmer in the week ended 7 October, bolstered by firmer market discussions amid unabated supply shortfalls. Fresh spot October MMA business materialised in the week, against a backdrop of a persistent constrained supply scenario outweighing consumer demand. A couple of 20-300 tonnes MMA cargoes were understood to have fetched the mid $1,800s/tonne CFR southeast Asia for October delivery. A 20-40 tonne size MMA shipment of southeast Asia origin was also negotiated at the low $1,800s/tonne CFR southeast Asia for October delivery. Market sentiment was driven by supply availability across the region being squeezed, even as downstream polymethyl methacrylate demand in southeast Asia was stable yet not particularly robust, market sources said. Taking into consideration the current firm market climate where a majority of regional suppliers are at short positions, a buildup in inventories is needed to alleviate the supply crunch situation, a southeast Asia based market source said. The buoyant market mood comes even as markets in China were closed for the Golden Week National holiday. Several market players characterised the current tight-supplied market as one which leaned towards sellers, or a ‘merchants’ market’ somewhat, leaving limited room for negotiation on the buying side. Asking levels on the selling side for MMA spot shipments in 20- 300 tonnes were near $1,880/tonne CFR southeast Asia, while market sources viewed workable levels for trades to be carried out at the low to mid $1,800s/tonne CFR southeast Asia. However, there was also market concern on the narrowing spread between raw material MMA and downstream PMMA prices, squeezing margins for downstream makers. This in part clouded market outlook in the near term, although regional sources as a whole saw prevailing MMA prices at their ceiling. On production, Asahi Kasei Corp has shut at the start of this week its 100,000 tonne/year methyl methacrylate (MMA) plant in Kawasaki for scheduled maintenance. The routine overhaul of the plant is expected to last about 40 days, in line with its initial maintenance plan. Still in Japan, Mitsubishi Gas Chemical Co (MGC) will delay the restart of its MMA plant in Niigata owing to unexpected mechanical problems, according to sources with knowledge of the matter. The plant is expected to resume operations in two weeks’ time or around 20 October. It was originally due to restart on 7 October following regular maintenance. The delayed restart comes in the wake of a lingering tight supply situation in Asia-Pacific. There were limited concrete discussions for MMA spot cargoes in 500 tonnes or more, with spot regional prices assessed in line with the upward movement for smaller shipments of 20-300 tonnes. Chinese domestic market Chinese domestic MMA markets were closed for the Golden Week public holiday. Other Regional Markets In South Korea, supply shortfalls against a backdrop of scheduled plant maintenance lent support to domestic prices. Spot MMA cargoes were discussed at Korean Won 1,970- 2,000/kg DEL for October, in lin ...
#    'enriched_text': {'sentiment': {'document': {'score': -0.383444,
#       'label': 'negative'}},
#     'entities': [{'count': 9,
#       'sentiment': {'score': -0.128232, 'label': 'negative'},
#       'text': 'Asia',
#       'relevance': 0.956821,
#       'type': 'Location',
#       'disambiguation': {'subtype': ['FieldOfStudy', 'Continent'],
#        'name': 'Asia',
#        'dbpedia_resource': 'http://dbpedia.org/resource/Asia'}},
#      {'count': 1,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': 'PMMA Southeast Asia Asia',
#       'relevance': 0.718544,
#       'type': 'JobTitle'},
#      {'count': 2,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': 'southeast Asia',
#       'relevance': 0.585465,
#       'type': 'Location',
#       'disambiguation': {'subtype': ['Region'],
#        'name': 'Southeast Asia',
#        'dbpedia_resource': 'http://dbpedia.org/resource/Southeast_Asia'}},
#      {'count': 1,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': 'MMA',
#       'relevance': 0.43114,
#       'type': 'Organization',
#       'disambiguation': {'subtype': [],
#        'name': 'MIDI Manufacturers Association',
#        'dbpedia_resource': 'http://dbpedia.org/resource/MIDI_Manufacturers_Association'}},
#      {'count': 4,
#       'sentiment': {'score': 0.455008, 'label': 'positive'},
#       'text': 'China',
#       'relevance': 0.410296,
#       'type': 'Location',
#       'disambiguation': {'subtype': ['Region',
#         'AdministrativeDivision',
#         'GovernmentalJurisdiction',
#         'Kingdom',
#         'FilmScreeningVenue',
#         'Country'],
#        'name': 'China',
#        'dbpedia_resource': 'http://dbpedia.org/resource/China'}},
#      {'count': 1,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': 'Asia Pacific',
#       'relevance': 0.392399,
#       'type': 'Company'},
#      {'count': 4,
#       'sentiment': {'score': -0.668684, 'label': 'negative'},
#       'text': 'US',
#       'relevance': 0.389583,
#       'type': 'Location',
#       'disambiguation': {'subtype': ['Region',
#         'AdministrativeDivision',
#         'GovernmentalJurisdiction',
#         'FilmEditor',
#         'Country'],
#        'name': 'United States',
#        'dbpedia_resource': 'http://dbpedia.org/resource/United_States'}},
#      {'count': 2,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': 'South Korea',
#       'relevance': 0.329478,
#       'type': 'Location',
#       'disambiguation': {'subtype': ['GovernmentalJurisdiction', 'Country'],
#        'name': 'South Korea',
#        'dbpedia_resource': 'http://dbpedia.org/resource/South_Korea'}},
#      {'count': 1,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': 'MT',
#       'relevance': 0.278131,
#       'type': 'Location',
#       'disambiguation': {'subtype': ['StateOrCounty']}},
#      {'count': 1,
#       'sentiment': {'score': -0.736629, 'label': 'negative'},
#       'text': 'US Federal Reserve',
#       'relevance': 0.274684,
#       'type': 'Organization',
#       'disambiguation': {'subtype': [],
#        'name': 'Federal Reserve System',
#        'dbpedia_resource': 'http://dbpedia.org/resource/Federal_Reserve_System'}},
#      {'count': 1,
#       'sentiment': {'score': -0.600739, 'label': 'negative'},
#       'text': 'OPEC',
#       'relevance': 0.260726,
#       'type': 'Organization',
#       'disambiguation': {'subtype': [],
#        'name': 'OPEC',
#        'dbpedia_resource': 'http://dbpedia.org/resource/OPEC'}},
#      {'count': 1,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': 'Asahi Kasei Corp',
#       'relevance': 0.249858,
#       'type': 'Company'},
#      {'count': 1,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': 'Japan',
#       'relevance': 0.23931,
#       'type': 'Location',
#       'disambiguation': {'subtype': ['Kingdom', 'Country'],
#        'name': 'Empire of Japan',
#        'dbpedia_resource': 'http://dbpedia.org/resource/Empire_of_Japan'}},
#      {'count': 1,
#       'sentiment': {'score': -0.6848, 'label': 'negative'},
#       'text': 'Asia-Pacific',
#       'relevance': 0.227814,
#       'type': 'Location',
#       'disambiguation': {'subtype': ['Country']}},
#      {'count': 1,
#       'sentiment': {'score': -0.272096, 'label': 'negative'},
#       'text': 'Niigata',
#       'relevance': 0.226668,
#       'type': 'Location',
#       'disambiguation': {'subtype': ['City']}},
#      {'count': 1,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': 'Mitsubishi Gas Chemical Co',
#       'relevance': 0.221203,
#       'type': 'Company'},
#      {'count': 1,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': 'Kawasaki',
#       'relevance': 0.2193,
#       'type': 'Company'},
#      {'count': 3,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': '300 tonnes',
#       'relevance': 0.2193,
#       'type': 'Quantity'},
#      {'count': 2,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': 'Four Weeks',
#       'relevance': 0.2193,
#       'type': 'Quantity'},
#      {'count': 1,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': '100,000 tonne',
#       'relevance': 0.2193,
#       'type': 'Quantity'},
#      {'count': 1,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': '500 tonnes',
#       'relevance': 0.2193,
#       'type': 'Quantity'},
#      {'count': 1,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': 'two weeks',
#       'relevance': 0.2193,
#       'type': 'Quantity'},
#      {'count': 1,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': '40 tonne',
#       'relevance': 0.2193,
#       'type': 'Quantity'},
#      {'count': 1,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': '40 days',
#       'relevance': 0.2193,
#       'type': 'Quantity'},
#      {'count': 1,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': '$1,880',
#       'relevance': 0.2193,
#       'type': 'Quantity'},
#      {'count': 1,
#       'sentiment': {'score': 0, 'label': 'neutral'},
#       'text': '9%',
#       'relevance': 0.2193,
#       'type': 'Quantity'}],
#     'concepts': [{'text': 'Southeast Asia',
#       'relevance': 0.975093,
#       'dbpedia_resource': 'http://dbpedia.org/resource/Southeast_Asia'},
#      {'text': 'Bangkok',
#       'relevance': 0.859623,
#       'dbpedia_resource': 'http://dbpedia.org/resource/Bangkok'},
#      {'text': 'Methyl methacrylate',
#       'relevance': 0.753152,
#       'dbpedia_resource': 'http://dbpedia.org/resource/Methyl_methacrylate'},
#      {'text': 'East Asia',
#       'relevance': 0.729478,
#       'dbpedia_resource': 'http://dbpedia.org/resource/East_Asia'},
#      {'text': 'Indonesia',
#       'relevance': 0.709404,
#       'dbpedia_resource': 'http://dbpedia.org/resource/Indonesia'},
#      {'text': 'Philippines',
#       'relevance': 0.708383,
#       'dbpedia_resource': 'http://dbpedia.org/resource/Philippines'},
#      {'text': 'Supply and demand',
#       'relevance': 0.680758,
#       'dbpedia_resource': 'http://dbpedia.org/resource/Supply_and_demand'},
#      {'text': 'Asia',
#       'relevance': 0.678402,
#       'dbpedia_resource': 'http://dbpedia.org/resource/Asia'}],
#     'categories': [{'score': 0.747379,
#       'label': '/business and industrial/energy/oil/oil and gas prices'},
#      {'score': 0.735083, 'label': '/finance/investing/day trading'},
#      {'score': 0.665804, 'label': '/finance/financial news'}]}}]}

# %%
dict={'a':1,'b':2,'c':3}
dict_list=[]
dict_list=list(dict.values())
print (dict_list)

# %%
with open('expansions.json', 'r') as f:
        datastore = json.load(f)
print('datastore \n',datastore)
datastorelist = datastore.values()
print('datastorelist \n',datastorelist)

# %%
expansions_list = discovery.list_expansions(environment_id, collection_id)
print(type(expansions_list), '\t', type(list(expansions_list.values())), (list(expansions_list.values())[0]))
print(json.dumps(expansions_list, indent=2))
expansion = json.dumps({
   "expansions": [
     {
       "expanded_terms": [
         "car",
         "automobile",
         "motor vehicle"
       ]
     }
   ]
 })
with open('expansions.json', 'r') as f:
        datastore = json.load(f)
print('datastore \t',datastore, '\n',type(datastore))
expansion_json = json.loads(expansion)

#d = {"age":25} 
kwargs = {"age":25}

datastore_list = list(datastore.values())
print(type(expansion),'\t',expansion)
print(type(expansion_json),'\t',expansion_json)
# ************ create is failing ***************** #
#expansions_list = discovery.create_expansions(environment_id,collection_id,list(datastore))
expansions_list = discovery.list_expansions(environment_id, collection_id)

print('expansions_list ********** \n',json.dumps(expansions_list, indent=2))

# %%
import json

r = {'is_claimed': 'True', 'rating': 3.5}
print(type(r)) #Output
r = json.dumps(r)
loaded_r = json.loads(r)
loaded_r['rating'] #Output 3.5
print(type(r)) #Output str
print(type(loaded_r)) #Output dict

# %%
def list_collections(self, environment_id):
        """
        Retrieves information about the collections within a given environment
        :param environment_id: this is the guid of a valid environment
        :return: json results of the collections in an environment
        """
        url_string = '/v1/environments/{0}/collections'.format(
            environment_id)
        return self.request(method='GET', url=url_string,
                            params={"version": self.version},
                            accept_json=True)
list_collections(discovery,environment_id)

# %%
import json
from ibm_watson import DiscoveryV1

discovery = DiscoveryV1(
    version="2019-04-30",
    iam_apikey="V8WkcjRtkyrWKy2O17_24HDqqI1BeylblhjakwhxHb_x",
    url="{url}"
)

response = discovery.create_environment(
    name="my_environment",
    description="My environment"
).get_result()

print(json.dumps(response, indent=2))

# %%
# collection name - Discover demo
service_url ="https://api.eu-gb.discovery.watson.cloud.ibm.com/instances/876489a7-d86c-454f-adde-8b04667dd78b"
api_key="8h5LDFya1JAX6f2xi6t3JOtNc2foqFJY00YRgtQOmAt_"
environment_id = "21ffc184-085f-4c90-aa90-00828f1f86ec"
configuration_id= "35992af5-33e1-4207-b809-c380c8be39e0"
collection_id = "55e69f31-8849-43e4-992e-3f3e5915ae91"

# %%
authenticator = IAMAuthenticator(api_key)

discovery = DiscoveryV1(
    version='2018-03-05',
    authenticator=authenticator
)

discovery.set_service_url(service_url)

# %%
response= discovery.query(environment_id, collection_id, filter=None, query=None, natural_language_query='four weeks ago', 
                passages=True,
                #aggregation= 'term(classname).top_hits(5)', 
      count=None, return_fields=None, offset=None, sort=None, highlight=None, 
      passages_fields=None, passages_count=None, passages_characters=None, deduplicate=None, deduplicate_field=None)
# print(len(response['passages']))
response
